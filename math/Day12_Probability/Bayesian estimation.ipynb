# %%
xx = np.linspace(0, 1, 1000)
a0, b0 = 1, 1
plt.plot(xx, sp.stats.beta(a0, b0).pdf(xx))
a, b = 7, 5
plt.plot(xx, sp.stats.beta(a, b).pdf(xx))
plt.show()
# %matplotlib inline

# %%
xx = np.linspace(0, 1, 1000)
a0, b0 = 1+2, 1+1
plt.plot(xx, sp.stats.beta(a0, b0).pdf(xx))
a, b = 1 + 60, 1+ 40
plt.plot(xx, sp.stats.beta(a, b).pdf(xx))
plt.show()
# %matplotlib inline

# %%
xx = np.linspace(0, 1, 1000)
a0, b0 = 1+2, 1+1
a, b = 1+ 60, 2+40
plt.plot(sp.stats.beta(a0, b0).pdf(xx))
plt.plot(sp.stats.beta(a, b).pdf(xx))
plt.show()

# %matplotlib inline

# %% [markdown]
# --------

# %% [markdown]
# # 연습문제 9.3.2

# %%
from sklearn.datasets import load_iris
data = load_iris()

# %%
x = data.data[:, 0]

# %%
N = len(x)
mu0, sigma20 = 1, 1
mu, sigma2 = np.mean(x), np.var(x)
xx = np.linspace(5.82, 5.86, 1000)
mu0 = sigma2/(N*sigma20 + sigma2) * mu0 + (N*sigma20)/(N*sigma20 + sigma2)*x.mean()
sigma20 = 1/(1/sigma20 + N/sigma2)
plt.plot(xx, sp.stats.norm(mu0, sigma20).pdf(xx))
plt.show()
# %matplotlib inline
print(f"{round(mu0, 2)}")
# Out:
# 5.82
