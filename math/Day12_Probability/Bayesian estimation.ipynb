# %%
xx = np.linspace(0, 1, 1000)
a0, b0 = 1, 1
plt.plot(xx, sp.stats.beta(a0, b0).pdf(xx))
a, b = 7, 5
plt.plot(xx, sp.stats.beta(a, b).pdf(xx))
plt.show()
# %matplotlib inline

# %%
xx = np.linspace(0, 1, 1000)
a0, b0 = 1+2, 1+1
plt.plot(xx, sp.stats.beta(a0, b0).pdf(xx))
a, b = 1 + 60, 1+ 40
plt.plot(xx, sp.stats.beta(a, b).pdf(xx))
plt.show()
# %matplotlib inline
