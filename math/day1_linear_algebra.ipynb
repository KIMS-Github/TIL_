# %% [markdown]
# ### practice 2.2.3
# 1. 내적으로 1번이미지와 10번 이미지의 유사도를 구하라
# 2. 내적을 이용하여 모든 이미지의 조합에 대하여 유사도를 구하라(행렬과 행렬의 곱)

# %%
from sklearn.datasets import load_digits
import seaborn as sns
X = load_digits().data

# %%
# 1. 
a = X[0] # 0번째 벡터
b = X[9]# 10번째 벡터
a@b
# Out:
# 2807.0

# %%
a = X@X.T
sns.heatmap(a, cmap=plt.cm.bone_r)
plt.show()
# %matplotlib inline
