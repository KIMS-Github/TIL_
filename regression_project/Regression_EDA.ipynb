# %%
pd.options.display.max_rows = 9999
pd.options.display.max_columns = 9999

import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline
rc('font', family='AppleGothic')

plt.rcParams['axes.unicode_minus'] = False

# %%
raw_df = pd.read_csv("resources/2016_1분기보고서_03_포괄손익계산서_20190418.txt",sep = "\t",  engine='python', encoding = "cp949")

# %% [markdown]
# # 포괄손익계산서 Statement of comprehensive income , 包括損益計算書

# %% [markdown]
# 정기간 동안 기업이 달성한 경영성과를 보여주기 위해 한국채택국제회계기준에서 요구하는 재무제표로, 총포괄손익(주주와의 자본거래를 제외한 모든 거래로 인해 발생한 자본의 변동)에 <br> 해당하는 당기순손익과 기타포괄손익 정보(총포괄손익에 포함되지만 당기손익이 아닌 수익과 비용)를 제공한다.

# %%
raw_df.head(5)
# Out:
#                                재무제표종류      종목코드 회사명       시장구분   업종       업종명  \
# 0  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [060310]  3S  코스닥시장상장법인  262  전자부품 제조업
# 1  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [060310]  3S  코스닥시장상장법인  262  전자부품 제조업
# 2  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [060310]  3S  코스닥시장상장법인  262  전자부품 제조업
# 3  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [060310]  3S  코스닥시장상장법인  262  전자부품 제조업
# 4  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [060310]  3S  코스닥시장상장법인  262  전자부품 제조업
#
#    결산월       결산기준일   보고서종류   통화  \
# 0    3  2016-06-30  1분기보고서  KRW
# 1    3  2016-06-30  1분기보고서  KRW
# 2    3  2016-06-30  1분기보고서  KRW
# 3    3  2016-06-30  1분기보고서  KRW
# 4    3  2016-06-30  1분기보고서  KRW
#
#                                              항목코드       항목명     당기 1분기 3개월  \
# 0                                    ifrs_Revenue   수익(매출액)  5,975,861,071
# 1                                ifrs_CostOfSales      매출원가  4,997,565,721
# 2                                ifrs_GrossProfit     매출총이익    978,295,350
# 3  dart_TotalSellingGeneralAdministrativeExpenses   판매비와관리비    948,485,967
# 4                        dart_OperatingIncomeLoss  영업이익(손실)     29,809,383
#
#        당기 1분기 누적     전기 1분기 3개월      전기 1분기 누적              전기             전전기
# 0  5,975,861,071  5,116,455,520  5,116,455,520  19,425,637,572  21,104,219,053
# 1  4,997,565,721  4,353,993,084  4,353,993,084  16,195,826,820  19,807,461,698
# 2    978,295,350    762,462,436    762,462,436   3,229,810,752   1,296,757,355
# 3    948,485,967    650,779,885    650,779,885   2,324,704,067   5,402,979,409
# 4     29,809,383    111,682,551    111,682,551     905,106,685  -4,106,222,054

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39919 entries, 0 to 39918
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   재무제표종류      39919 non-null  object
#  1   종목코드        39919 non-null  object
#  2   회사명         39919 non-null  object
#  3   시장구분        39919 non-null  object
#  4   업종          39919 non-null  int64
#  5   업종명         39919 non-null  object
#  6   결산월         39919 non-null  int64
#  7   결산기준일       39919 non-null  object
#  8   보고서종류       39919 non-null  object
#  9   통화          39919 non-null  object
#  10  항목코드        39919 non-null  object
#  11  항목명         39917 non-null  object
#  12  당기 1분기 3개월  34665 non-null  object
#  13  당기 1분기 누적   34638 non-null  object
#  14  전기 1분기 3개월  34452 non-null  object
#  15  전기 1분기 누적   34426 non-null  object
#  16  전기          36565 non-null  object
#  17  전전기         36320 non-null  object
# dtypes: int64(2), object(16)
# memory usage: 5.5+ MB

# %% [markdown]
# ## <font color = "#DAF7A6"> * missing values

# %%
raw_df.isnull().sum()
# Out:
# 재무제표종류           0
# 종목코드             0
# 회사명              0
# 시장구분             0
# 업종               0
# 업종명              0
# 결산월              0
# 결산기준일            0
# 보고서종류            0
# 통화               0
# 항목코드             0
# 항목명              2
# 당기 1분기 3개월    5254
# 당기 1분기 누적     5281
# 전기 1분기 3개월    5467
# 전기 1분기 누적     5493
# 전기            3354
# 전전기           3599
# dtype: int64

# %% [markdown]
# ### <font color = "#DAF7A5"> drop columns

# %%
df = raw_df[['종목코드', '회사명','항목명', '당기 1분기 누적']]
df.head()
# Out:
#        종목코드 회사명       항목명      당기 1분기 누적
# 0  [060310]  3S   수익(매출액)  5,975,861,071
# 1  [060310]  3S      매출원가  4,997,565,721
# 2  [060310]  3S     매출총이익    978,295,350
# 3  [060310]  3S   판매비와관리비    948,485,967
# 4  [060310]  3S  영업이익(손실)     29,809,383

# %%
df["항목명"] = df["항목명"].apply(lambda x :  str(x).replace(" ",""))
df_list = ["매출액","당기순이익","금융비용","금융원가","감가상각비","무형자산상각비","매출원가","판매관리비"]
df[df["항목명"].str.contains("매출액","당기순이익")]
# Out:
#            종목코드              회사명                       항목명           당기 1분기 누적
# 0      [060310]               3S                   수익(매출액)       5,975,861,071
# 74     [054620]            AP시스템                   수익(매출액)      35,352,899,194
# 92     [211270]           AP위성통신                       매출액       2,236,550,468
# 113    [027410]           BGF리테일                       매출액   1,067,180,507,431
# 134    [001460]              BYC                     Ⅰ.매출액      44,389,968,988
# 157    [032040]          C&S자산관리                       매출액      48,093,649,629
# 188    [079160]           CJ CGV                       매출액     204,138,133,297
# 208    [130960]           CJ E&M                       매출액     289,597,782,947
# 243    [011150]            CJ씨푸드                       매출액      42,764,159,463
# 296    [097950]           CJ제일제당                   수익(매출액)   1,222,647,265,000
# 319    [051500]          CJ프레시웨이                       매출액     404,967,781,591
# 349    [058820]            CMG제약                   수익(매출액)       7,542,133,068
# 366    [023460]              CNH                   수익(매출액)       1,837,377,836
# 367    [023460]              CNH                 이자수익(매출액)         977,666,556
# 371    [023460]              CNH                 배당수익(매출액)                   0
# 394    [065770]               CS                       매출액       6,530,037,546
# 422    [083660]          CSA 코스믹                       매출액       3,668,326,663
# 472    [068790]              DMS                     I.매출액      43,550,977,904
# 525    [069730]            DSR제강                       매출액      40,486,536,906
# 576    [037370]               EG                       매출액      20,345,675,667
# 597    [079190]              EMW                     I.매출액      17,318,261,069
# 619    [007700]              F&F                   수익(매출액)      91,636,243,229
# 640    [114090]              GKL                   수익(매출액)     136,621,964,964
# 660    [032860]        GMR 머티리얼즈                   수익(매출액)       9,770,405,206
# 690    [083450]              GST                       매출액      11,993,220,190
# 758    [078150]          HB테크놀러지                   수익(매출액)      35,035,704,773
# 778    [036640]              HRS                       매출액      12,926,770,735
# 799    [095340]              ISC                       매출액      19,816,144,054
# 815    [099520]           ITX엠투엠                   수익(매출액)       6,872,876,065
# 836    [067290]             JW신약                       매출액      20,316,957,338
# 855    [001060]           JW중외제약                       매출액     119,235,907,731
# 896    [035900]         JYP Ent.                       매출액       9,961,606,219
# 922    [021320]            KCC건설                       매출액     231,365,142,336
# 1013   [036670]              KCI                   수익(매출액)       9,424,903,303
# 1056   [119650]            KC코트렐                       매출액      41,244,214,301
# 1080   [044180]             KD건설                   수익(매출액)       6,807,598,966
# 1120   [151860]           KG ETS                   수익(매출액)      23,877,160,452
# 1142   [109070]              KGP                       매출액      11,491,570,344
# 1164   [046440]          KG모빌리언스                   수익(매출액)      35,602,998,722
# 1181   [035600]           KG이니시스                       매출액      79,886,159,763
# 1209   [001390]            KG케미칼                       매출액      37,864,379,318
# 1226   [060720]             KH바텍                   수익(매출액)      60,362,728,230
# 1271   [122450]              KMH                   수익(매출액)       7,865,980,413
# 1291   [052900]           KMH하이텍                   수익(매출액)       9,506,269,100
# 1326   [083420]         KPX그린케미칼                       매출액      58,536,344,946
# 1348   [114450]          KPX생명과학                   수익(매출액)       8,619,761,032
# 1369   [025000]           KPX케미칼                       매출액     106,060,226,837
# 1411   [000040]            KR모터스                       매출액      18,791,545,861
# 1445   [044450]            KSS해운                       매출액      36,287,719,102
# 1449   [044450]            KSS해운   용역의제공으로인한수익(매출액)에대한매출원가      26,028,490,096
# 1526   [058850]             KTcs                   수익(매출액)     107,565,687,743
# 1572   [093050]               LF                       매출액     343,339,287,965
# 1642   [068870]           LG생명과학                       매출액     114,739,311,539
# 1713   [079550]           LIG넥스원                   수익(매출액)     401,209,588,449
# 1768   [000680]           LS네트웍스                   수익(매출액)     122,596,558,411
# 1811   [159910]              MBK                       매출액       4,306,857,611
# 1830   [086960]            MDS테크                       매출액      18,761,370,251
# 1848   [023150]            MH에탄올                       매출액      12,189,421,794
# 1866   [065150]              MPK                       매출액      25,366,142,702
# 1948   [060250]       NHN한국사이버결제                   수익(매출액)      59,604,301,420
# 2024   [008260]             NI스틸                   수익(매출액)      24,265,641,502
# 2055   [024940]             PN풍년                   수익(매출액)      19,645,053,875
# 2070   [091340]           S&K폴리텍                       매출액       7,570,514,334
# 2089   [100840]             S&TC                       매출액      66,747,229,831
# 2109   [064960]           S&T모티브                       매출액     196,124,287,489
# 2128   [003570]           S&T중공업                       매출액      91,209,267,423
# 2164   [010950]            S-Oil                       매출액   3,428,420,000,000
# 2252   [036120]          SCI평가정보                   수익(매출액)       7,582,898,141
# 2276   [099220]              SDN                       매출액       6,219,823,639
# 2299   [036540]           SFA반도체                   수익(매출액)      49,224,623,939
# 2320   [040610]             SG&G                   수익(매출액)       9,983,387,983
# 2342   [049470]              SGA                   수익(매출액)       6,080,790,853
# 2362   [184230]          SGA솔루션즈                       매출액       4,255,526,218
# 2385   [004060]           SG세계물산                       매출액      74,547,101,299
# 2430   [052300]           SH 홀딩스                   수익(매출액)       2,897,560,752
# 2464   [002360]          SH에너지화학                       매출액      49,429,744,867
# 2483   [009160]           SIMPAC                       매출액      59,001,614,987
# 2503   [090730]  SIMPAC METALLOY                       매출액      28,223,613,377
# 2539   [011790]              SKC                       매출액     356,544,164,957
# 2561   [057500]          SKC 솔믹스                   수익(매출액)      31,470,640,025
# 2581   [178920]         SKC코오롱PI                       매출액      36,784,728,619
# 2600   [018670]             SK가스                       매출액     726,149,364,274
# 2622   [001740]           SK네트웍스                       매출액   4,319,905,605,240
# 2644   [210980]            SK디앤디                       매출액      53,194,749,646
# 2668   [036490]          SK머티리얼즈                       매출액      84,892,894,476
# 2689   [096770]          SK이노베이션                       매출액     398,238,582,000
# 2720   [006120]            SK케미칼                       매출액     245,524,789,509
# 2750   [000660]           SK하이닉스                       매출액   3,484,735,000,000
# 2773   [048550]           SM C&C                   수익(매출액)      20,492,775,928
# 2817   [077970]            STX엔진                       매출액      95,776,000,000
# 2848   [071970]           STX중공업                   수익(매출액)     131,953,344,396
# 2865   [002710]            TCC동양                       매출액      77,890,608,157
# 2892   [032540]            TJ미디어                       매출액      13,785,758,745
# 2912   [048770]              TPC                       매출액      16,303,000,912
# 2984   [024070]           WISCOM                       매출액      30,533,838,272
# 3004   [037270]          YG PLUS                       매출액       5,512,884,826
# 3023   [040300]              YTN                       매출액      24,290,404,751
# 3051   [051390]               YW                       매출액       5,678,028,075
# 3101   [079940]              가비아                   수익(매출액)      12,340,508,309
# 3162   [078890]            가온미디어                       매출액     107,857,815,592
# 3181   [000500]             가온전선                       매출액     175,837,327,546
# 3202   [030270]               가희                   수익(매출액)       9,357,890,533
# 3203   [030270]               가희           재화의판매로인한수익(매출액)       9,357,890,533
# 3205   [030270]               가희    재화의판매로인한수익(매출액)에대한매출원가      11,141,008,782
# 3272   [024840]             갑을메탈                       매출액      87,987,780,434
# 3298   [000860]           강남제비스코                       매출액      57,634,152,549
# 3318   [217730]          강스템바이오텍                       매출액         492,863,182
# 3360   [011420]          갤럭시아에스엠                   수익(매출액)       8,558,604,071
# 3380   [094480]           갤럭시아컴즈                   수익(매출액)      11,403,368,125
# 3402   [063080]              게임빌                   수익(매출액)      33,270,697,591
# 3419   [039240]             경남스틸                   수익(매출액)      62,737,413,576
# 3439   [008020]            경남에너지                   수익(매출액)     234,967,046,032
# 3460   [053950]             경남제약                   수익(매출액)       9,028,438,716
# 3478   [002100]               경농                       매출액      78,409,728,151
# 3502   [012320]           경동도시가스                   수익(매출액)     360,085,143,874
# 3537   [011040]             경동제약                       매출액      36,201,431,604
# 3588   [139050]               경봉                       매출액       8,248,519,856
# 3608   [012610]             경인양행                       매출액      43,032,446,261
# 3627   [009140]             경인전자                   수익(매출액)       3,007,117,289
# 3628   [009140]             경인전자           재화의판매로인한수익(매출액)       2,907,175,354
# 3629   [009140]             경인전자                 기타수익(매출액)          99,941,935
# 3631   [009140]             경인전자    재화의판매로인한수익(매출액)에대한매출원가       2,590,104,579
# 3632   [009140]             경인전자          기타수익(매출액)에대한매출원가                   0
# 3695   [024910]             경창산업                       매출액     131,283,475,998
# 3732   [012200]             계양전기                       매출액      76,350,010,603
# 3765   [089890]            고려반도체                   수익(매출액)      12,039,351,313
# 3781   [002140]             고려산업                       매출액      42,174,750,636
# 3828   [010130]             고려아연                       매출액   1,165,572,929,514
# 3851   [002240]             고려제강                       매출액     108,682,644,159
# 3872   [014570]             고려제약                   수익(매출액)      10,974,856,067
# 3891   [009810]            고려포리머                   수익(매출액)       4,682,639,748
# 3917   [098460]               고영                   수익(매출액)      34,664,776,788
# 3938   [215000]              골프존                       매출액      52,263,809,691
# 3954   [121440]         골프존유원홀딩스                   수익(매출액)      10,414,211,348
# 3976   [009290]             광동제약                   수익(매출액)     136,086,178,739
# 4022   [017040]             광명전기                       매출액      18,905,083,915
# 4061   [037710]            광주신세계                       매출액      52,972,796,983
# 4081   [026910]             광진실업                   수익(매출액)       9,703,420,552
# 4103   [090150]             광진윈텍                       매출액      22,775,074,508
# 4121   [140910]             광희리츠                   수익(매출액)      13,463,033,060
# 4122   [140910]             광희리츠          용역의제공으로인한수익(매출액)      13,463,033,060
# 4124   [140910]             광희리츠   용역의제공으로인한수익(매출액)에대한매출원가      10,183,964,960
# 4142   [053270]             구영테크                       매출액      18,376,526,916
# 4163   [007690]             국도화학                       매출액     170,567,720,854
# 4183   [005320]               국동                   수익(매출액)      32,721,487,438
# 4205   [001140]               국보                   수익(매출액)      19,905,225,901
# 4250   [066620]            국보디자인                   수익(매출액)      33,740,755,011
# 4270   [043650]              국순당                       매출액      16,126,391,389
# 4293   [006050]            국영지앤엠                       매출액       9,991,803,863
# 4319   [078130]             국일제지                       매출액       9,462,566,396
# 4364   [002720]             국제약품                       매출액      27,621,588,436
# 4387   [019010]           그랜드백화점                   수익(매출액)      17,767,509,659
# 4405   [014530]             극동유화                   수익(매출액)      52,999,744,845
# 4462   [014280]             금강공업                   수익(매출액)     100,544,997,967
# 4487   [053260]             금강철강                   수익(매출액)      36,380,877,294
# 4507   [008870]               금비                   수익(매출액)      23,392,100,839
# 4529   [058370]             금성테크                       매출액       3,529,493,595
# 4549   [001570]               금양                   수익(매출액)      40,213,841,448
# 4601   [214330]           금호에이치티                       매출액      47,249,163,963
# 4623   [130500]             금호엔티                   수익(매출액)      11,153,559,659
# 4641   [001210]             금호전기                   수익(매출액)      19,631,471,655
# 4665   [073240]            금호타이어                       매출액     573,731,515,486
# 4687   [036190]           금화피에스시                       매출액      44,208,396,065
# 4711   [049080]             기가레인                       매출액      17,024,403,839
# 4733   [035460]            기산텔레콤                   수익(매출액)       3,881,477,138
# 4755   [092440]             기신정기                       매출액      24,592,088,000
# 4786   [013700]            까뮤이앤씨                   수익(매출액)      33,129,680,719
# 4872   [187790]               나노                       매출액       4,907,348,518
# 4892   [151910]              나노스                   수익(매출액)                 NaN
# 4917   [121600]            나노신소재                   수익(매출액)       9,491,362,964
# 4980   [039860]             나노엔텍                       매출액       4,509,170,276
# 5000   [091970]             나노캠텍                       매출액       8,486,681,995
# 5019   [051490]            나라엠앤디                       매출액      20,284,879,528
# 5067   [190510]              나무가                       매출액      64,173,437,855
# 5090   [138610]              나이벡                       매출액       1,201,369,026
# 5108   [130580]           나이스디앤비                   수익(매출액)       5,124,858,675
# 5129   [036800]          나이스정보통신                   수익(매출액)      69,478,052,717
# 5153   [001260]             남광토건                       매출액      46,087,514,899
# 5177   [008350]            남선알미늄                       매출액      83,367,321,138
# 5233   [002070]            남영비비안                       매출액      38,144,443,225
# 5253   [025860]             남해화학                       매출액     292,051,765,118
# 5274   [091590]             남화토건                   수익(매출액)      10,799,392,737
# 5275   [091590]             남화토건           건설계약으로인한수익(매출액)      10,799,392,737
# 5277   [091590]             남화토건    건설계약으로인한수익(매출액)에대한매출원가       9,505,218,923
# 5294   [168330]           내츄럴엔도텍                       매출액       1,404,518,296
# 5365   [072770]        네오디안테크놀로지                       매출액       8,257,279,442
# 5388   [212560]             네오오토                   수익(매출액)      32,657,206,894
# 5419   [085910]             네오티스                       매출액      10,125,866,133
# 5443   [092730]              네오팜                       매출액      12,292,813,055
# 5464   [101400]           네오피델리티                   수익(매출액)      10,569,363,806
# 5496   [007390]             네이처셀                   수익(매출액)       6,517,973,422
# 5556   [033640]              네패스                   수익(매출액)      53,095,290,249
# 5576   [087730]           네패스신소재                       매출액       4,939,780,309
# 5597   [005720]               넥센                   수익(매출액)      54,832,389,941
# 5599   [005720]               넥센                 배당수익(매출액)       8,463,003,629
# 5600   [005720]               넥센                 기타수익(매출액)       1,012,312,731
# 5621   [002350]            넥센타이어                   수익(매출액)     360,710,234,502
# 5653   [073070]             넥센테크                   수익(매출액)      22,984,534,345
# 5673   [110570]              넥솔론                   수익(매출액)      55,059,098,199
# 5701   [089140]              넥스턴                   수익(매출액)       2,991,509,783
# 5720   [065170]            넥스트BT                   수익(매출액)       6,826,238,920
# 5758   [137940]            넥스트아이                       매출액                 NaN
# 5759   [137940]            넥스트아이           재화의판매로인한수익(매출액)       6,284,911,657
# 5761   [137940]            넥스트아이    재화의판매로인한수익(매출액)에대한매출원가       4,646,195,251
# 5780   [092600]             넥스트칩                   수익(매출액)      18,880,653,797
# 5799   [041140]             넥슨지티                       매출액      19,968,585,551
# 5830   [006280]              녹십자                       매출액     208,530,936,637
# 5854   [031390]             녹십자셀                       매출액       2,779,508,732
# 5881   [142280]           녹십자엠에스                       매출액      19,978,978,083
# 5952   [040160]            누리텔레콤                       매출액       9,656,197,519
# 5974   [069140]             누리플랜                       매출액       5,761,964,906
# 5994   [126870]              뉴로스                       매출액      10,298,367,771
# 6015   [060260]              뉴보텍                       매출액       6,388,541,019
# 6035   [012340]              뉴인텍                       매출액      12,004,219,374
# 6056   [222040]          뉴트리바이오텍                       매출액      26,480,158,510
# 6078   [900100]            뉴프라이드                   수익(매출액)           9,190,687
# 6095   [085670]             뉴프렉스                       매출액      37,102,225,456
# 6114   [053290]             능률교육                   수익(매출액)      14,870,762,176
# 6115   [053290]             능률교육                     제품매출액      12,389,793,836
# 6116   [053290]             능률교육                     상품매출액         571,942,303
# 6117   [053290]             능률교육                     기타매출액       1,909,026,037
# 6138   [222810]             닉스테크                   수익(매출액)       1,941,761,838
# 6139   [222810]             닉스테크                     상품매출액         633,601,389
# 6140   [222810]             닉스테크                     제품매출액         400,548,344
# 6163   [119860]              다나와                   수익(매출액)       8,124,382,185
# 6190   [093640]          다믈멀티미디어                   수익(매출액)       6,002,603,188
# 6210   [039560]           다산네트웍스                       매출액       6,826,533,953
# 6230   [023590]             다우기술                       매출액      65,050,338,286
# 6250   [032190]            다우데이타                       매출액      28,929,226,851
# 6267   [020120]            다우인큐브                       매출액       6,155,461,370
# 6288   [068240]             다원시스                   수익(매출액)      12,412,006,822
# 6308   [015590]           대경기계기술                   수익(매출액)      46,334,298,975
# 6350   [004130]            대덕GDS                     I.매출액     116,073,444,423
# 6373   [008060]             대덕전자                       매출액     103,694,652,488
# 6393   [000490]             대동공업                   수익(매출액)     136,848,357,798
# 6418   [020400]             대동금속                       매출액      14,554,636,874
# 6437   [008830]             대동기어                       매출액      28,791,007,652
# 6464   [048470]             대동스틸                       매출액      15,412,647,416
# 6483   [008110]             대동전자                   수익(매출액)       2,293,729,075
# 6505   [004780]             대륙제관                   수익(매출액)      43,702,919,271
# 6565   [004440]           대림씨엔에스                       매출액      69,495,034,156
# 6566   [004440]           대림씨엔에스                     상품매출액       1,303,277,800
# 6567   [004440]           대림씨엔에스                     제품매출액      47,609,947,720
# 6590   [017650]             대림제지                   수익(매출액)      14,156,157,505
# 6609   [006570]             대림통상                       매출액      35,342,848,601
# 6677   [007720]          대명코퍼레이션                       매출액      43,380,513,992
# 6700   [078140]            대봉엘에스                   수익(매출액)      15,732,603,161
# 6717   [001680]               대상                       매출액     446,120,933,751
# 6739   [084690]            대상홀딩스                       매출액       8,246,663,054
# 6760   [036480]            대성미생물                     Ⅰ.매출액       7,808,861,208
# 6778   [128820]             대성산업                   수익(매출액)     179,966,378,845
# 6802   [117580]            대성에너지                       매출액     312,769,725,530
# 6843   [025440]             대성엘텍                       매출액      87,622,616,464
# 6859   [104040]            대성파인텍                       매출액      11,868,692,734
# 6885   [016710]            대성홀딩스                       매출액      11,577,125,562
# 6920   [020180]           대신정보통신                   수익(매출액)      25,356,849,614
# 6943   [009190]             대양금속                       매출액      32,610,257,871
# 6965   [108380]           대양전기공업                   수익(매출액)      29,705,807,193
# 6984   [006580]             대양제지                       매출액      24,258,989,438
# 7003   [014160]             대영포장                   수익(매출액)      58,445,012,379
# 7036   [009320]             대우부품                       매출액      13,644,223,826
# 7069   [003090]               대웅           재화의판매로인한수익(매출액)       1,470,885,963
# 7070   [003090]               대웅          용역의제공으로인한수익(매출액)       6,415,458,651
# 7071   [003090]               대웅                로열티수익(매출액)       2,464,929,889
# 7072   [003090]               대웅                 배당수익(매출액)       3,390,947,700
# 7075   [003090]               대웅    재화의판매로인한수익(매출액)에대한매출원가      -1,328,762,691
# 7096   [069620]             대웅제약                   수익(매출액)     190,451,873,606
# 7139   [048910]            대원미디어                       매출액      10,805,591,605
# 7181   [006340]             대원전선                   수익(매출액)      91,773,402,861
# 7200   [003220]             대원제약                       매출액      57,447,652,808
# 7201   [003220]             대원제약                     제품매출액      52,794,741,861
# 7202   [003220]             대원제약                     상품매출액       4,235,901,247
# 7203   [003220]             대원제약                     기타매출액         417,009,700
# 7281   [024890]             대원화성                   수익(매출액)      32,768,081,806
# 7301   [000300]            대유신소재                       매출액      52,519,194,632
# 7323   [002880]            대유에이텍                       매출액      87,732,987,647
# 7343   [120240]             대정화금                       매출액      14,487,435,073
# 7373   [003310]             대주산업                   수익(매출액)      22,501,078,397
# 7395   [078600]           대주전자재료                   수익(매출액)      11,858,178,717
# 7417   [065690]            대진디엠피                       매출액      13,600,547,829
# 7434   [012800]               대창                       매출액     127,256,053,142
# 7453   [015230]             대창단조                       매출액      37,342,334,580
# 7471   [096350]            대창솔루션                   수익(매출액)       8,327,568,114
# 7491   [140520]             대창스틸                   수익(매출액)      56,711,393,338
# 7515   [131220]             대한과학                       매출액       9,609,227,915
# 7532   [010170]            대한광통신                   수익(매출액)      23,230,090,830
# 7557   [054670]             대한뉴팜                   수익(매출액)      24,085,545,530
# 7578   [001070]             대한방직                       매출액      55,219,218,537
# 7597   [023910]             대한약품                   수익(매출액)      34,171,254,545
# 7617   [006650]             대한유화                       매출액     391,150,592,439
# 7636   [001440]             대한전선                       매출액     259,910,918,000
# 7658   [084010]             대한제강                       매출액     151,114,862,775
# 7682   [001790]             대한제당                   수익(매출액)     268,672,779,000
# 7752   [001130]             대한제분                       매출액      80,838,428,937
# 7798   [005880]             대한해운                       매출액     108,019,598,726
# 7822   [003830]             대한화섬                       매출액      26,192,689,192
# 7863   [069460]            대호에이엘                   수익(매출액)      27,829,363,109
# 7890   [021040]            대호피앤씨                   수익(매출액)      46,993,448,117
# 7916   [067080]             대화제약                   수익(매출액)      19,800,263,038
# 7934   [192080]           더블유게임즈                   수익(매출액)      37,578,077,237
# 7935   [192080]           더블유게임즈          용역의제공으로인한수익(매출액)      37,578,077,237
# 7995   [012510]            더존비즈온                       매출액      41,116,441,696
# 8011   [213420]           덕산네오룩스                       매출액      13,204,639,094
# 8030   [077360]           덕산하이메탈                   수익(매출액)      10,140,416,180
# 8051   [004830]               덕성                       매출액      23,898,947,520
# 8100   [090410]            덕신하우징                       매출액      29,118,915,025
# 8120   [024900]             덕양산업                       매출액     204,786,040,476
# 8159   [017680]             데코앤이                       매출액      10,788,167,394
# 8177   [206560]              덱스터                       매출액       6,128,311,856
# 8194   [008000]           도레이케미칼                       매출액     166,050,648,766
# 8215   [067990]           도이치모터스                   수익(매출액)     142,283,626,498
# 8270   [001620]             동국실업                       매출액      70,266,177,556
# 8291   [075970]           동국알앤에스                   수익(매출액)      16,274,435,298
# 8346   [023450]             동남합성                       매출액      20,245,540,710
# 8347   [023450]             동남합성                     제품매출액      17,311,316,307
# 8348   [023450]             동남합성                     상품매출액       1,863,916,793
# 8349   [023450]             동남합성                    임가공매출액       1,070,307,610
# 8412   [004140]               동방                       매출액     124,618,876,595
# 8437   [099410]             동방선기                   수익(매출액)       7,076,396,649
# 8455   [007590]            동방아그로                   수익(매출액)      66,857,229,169
# 8472   [012030]               동부                       매출액      45,679,130,742
# 8499   [005960]             동부건설                       매출액     121,169,703,791
# 8519   [045890]            동부라이텍                       매출액      15,705,989,583
# 8688   [002210]             동성제약                       매출액      20,375,678,153
# 8778   [102260]          동성코퍼레이션                       매출액      62,178,686,162
# 8803   [033500]            동성화인텍                   수익(매출액)     101,971,967,878
# 8829   [005190]             동성화학                       매출액      32,500,635,352
# 8852   [025950]             동신건설                   수익(매출액)      12,589,595,780
# 8891   [058730]            동아에스텍                       매출액      28,623,722,247
# 8940   [088130]             동아엘텍                   수익(매출액)       5,139,319,184
# 8961   [028100]             동아지질                       매출액      69,518,736,213
# 8986   [007340]          동아타이어공업                   수익(매출액)      87,948,371,735
# 9008   [041930]             동아화성                   수익(매출액)      34,890,035,195
# 9053   [002900]           동양물산기업                       매출액     109,296,758,381
# 9077   [038500]            동양시멘트                       매출액     120,970,531,248
# 9096   [060380]            동양에스텍                   수익(매출액)      29,903,970,937
# 9116   [079960]            동양이엔피                   수익(매출액)      91,460,848,003
# 9136   [008970]             동양철관                       매출액      23,444,250,350
# 9155   [104460]           동양피엔에프                       매출액      20,133,725,653
# 9176   [088910]               동우                   수익(매출액)      51,406,751,241
# 9197   [094170]            동운아나텍                       매출액      13,022,921,000
# 9219   [003580]               동원                   수익(매출액)       3,652,331,650
# 9246   [049770]            동원F&B                       매출액     393,524,891,116
# 9267   [013120]             동원개발                       매출액     141,605,870,105
# 9289   [018500]             동원금속                   수익(매출액)      77,149,654,770
# 9314   [006040]             동원산업                       매출액     167,090,238,812
# 9315   [006040]             동원산업                    어획물매출액      51,679,215,463
# 9316   [006040]             동원산업                     제품매출액      31,149,484,837
# 9317   [006040]             동원산업                     상품매출액      13,862,115,869
# 9318   [006040]             동원산업                     물류매출액      57,076,985,830
# 9319   [006040]             동원산업                     기타매출액      13,322,436,813
# 9345   [030720]             동원수산                   수익(매출액)      24,731,566,958
# 9369   [014820]           동원시스템즈                   수익(매출액)      96,966,714,318
# 9370   [014820]           동원시스템즈           재화의판매로인한수익(매출액)      59,830,271,799
# 9371   [014820]           동원시스템즈                     상품매출액      35,450,703,628
# 9373   [014820]           동원시스템즈                     기타매출액         758,894,115
# 9375   [014820]           동원시스템즈    재화의판매로인한수익(매출액)에대한매출원가      50,733,336,465
# 9377   [014820]           동원시스템즈   용역의제공으로인한수익(매출액)에대한매출원가         875,509,471
# 9378   [014820]           동원시스템즈          기타수익(매출액)에대한매출원가                 NaN
# 9397   [163560]           동일고무벨트                       매출액      59,038,970,096
# 9418   [109860]             동일금속                   수익(매출액)      15,301,999,483
# 9440   [032960]             동일기연                   수익(매출액)       6,458,225,469
# 9441   [032960]             동일기연                   수익(매출액)       6,458,225,469
# 9514   [004890]             동일산업                       매출액      66,578,758,286
# 9536   [002690]             동일제강                   수익(매출액)      22,886,032,792
# 9557   [019300]             동일제지                       매출액      54,054,491,131
# 9578   [023790]             동일철강                   수익(매출액)      14,405,010,766
# 9627   [025900]             동화기업                       매출액     102,274,608,851
# 9656   [000020]             동화약품                       매출액      59,230,458,275
# 9723   [078590]             두올산업                       매출액       9,338,826,220
# 9760   [073190]             디비케이                       매출액      10,192,688,091
# 9761   [073190]             디비케이                     제품매출액       7,779,944,196
# 9762   [073190]             디비케이                     상품매출액       2,216,729,923
# 9763   [073190]             디비케이                     용역매출액         126,716,432
# 9764   [073190]             디비케이                     기타매출액          69,297,540
# 9784   [066670]           디스플레이텍                   수익(매출액)      26,052,484,035
# 9804   [024090]              디씨엠                   수익(매출액)      30,348,575,862
# 9831   [092200]             디아이씨                       매출액      78,738,274,409
# 9854   [109740]            디에스케이                   수익(매출액)       9,086,627,514
# 9877   [090710]           디에스티로봇                   수익(매출액)       7,445,177,924
# 9897   [131030]         디에이치피코리아                   수익(매출액)       9,843,599,734
# 9919   [196490]         디에이테크놀로지                       매출액      18,334,483,485
# 9966   [092070]             디엔에프                   수익(매출액)      14,217,369,674
# 9992   [134580]              디엠티                   수익(매출액)      12,016,161,911
# 10012  [039840]               디오                   수익(매출액)      19,830,744,396
# 10041  [013570]              디와이                   수익(매출액)      22,810,082,670
# 10071  [210540]            디와이파워                   수익(매출액)      54,889,804,526
# 10092  [079810]             디이엔티                   수익(매출액)       7,786,775,041
# 10110  [113810]              디젠스                       매출액      16,166,142,171
# 10111  [113810]              디젠스                     제품매출액      16,166,142,171
# 10177  [043360]             디지아이                       매출액       5,616,310,381
# 10202  [106520]            디지탈옵틱                       매출액      13,564,120,238
# 10223  [068930]            디지털대성                   수익(매출액)       8,406,266,074
# 10265  [033310]          디케이디앤아이                   수익(매출액)       6,212,516,795
# 10289  [105740]             디케이락                       매출액      11,881,268,376
# 10308  [187220]             디티앤씨                       매출액       7,600,364,333
# 10324  [026890]              디피씨                       매출액       9,371,063,281
# 10387  [131180]               딜리                       매출액      10,858,226,319
# 10407  [042510]            라온시큐어                   수익(매출액)       3,157,177,477
# 10424  [050120]           라이브플렉스                   수익(매출액)      13,040,812,594
# 10445  [171120]            라이온켐텍                       매출액      27,657,517,833
# 10466  [115390]              락앤락                   수익(매출액)      51,522,197,896
# 10493  [084650]            랩지노믹스                       매출액       5,931,064,051
# 10532  [060300]             레드로버                       매출액      10,819,320,114
# 10569  [228850]             레이언스                       매출액      21,259,216,421
# 10588  [047440]              레이젠                   수익(매출액)      18,070,502,541
# 10589  [047440]              레이젠           재화의판매로인한수익(매출액)      17,599,841,214
# 10590  [047440]              레이젠                 기타수익(매출액)         470,661,327
# 10592  [047440]              레이젠    재화의판매로인한수익(매출액)에대한매출원가      16,628,933,222
# 10647  [026040]              로만손                       매출액      43,121,070,803
# 10666  [090360]             로보스타                       매출액      27,284,667,778
# 10714  [067730]             로지시스                       매출액       7,456,883,545
# 10757  [043710]            로켓모바일                   수익(매출액)         921,671,382
# 10781  [109960]             로코조이                       매출액       5,143,783,593
# 10846  [004000]           롯데정밀화학                       매출액     285,752,117,565
# 10936  [002270]             롯데푸드                       매출액     422,886,760,928
# 10961  [071840]           롯데하이마트                       매출액     887,700,695,530
# 10986  [038060]              루멘스                   수익(매출액)      85,748,170,287
# 11007  [082800]           루미마이크로                       매출액      16,698,411,329
# 11029  [085370]             루트로닉                   수익(매출액)      20,716,027,029
# 11030  [085370]             루트로닉           재화의판매로인한수익(매출액)      20,678,524,963
# 11031  [085370]             루트로닉                 기타수익(매출액)          37,502,066
# 11033  [085370]             루트로닉    재화의판매로인한수익(매출액)에대한매출원가       9,618,661,891
# 11034  [085370]             루트로닉          기타수익(매출액)에대한매출원가                   0
# 11060  [060240]            룽투코리아                   수익(매출액)       4,521,310,987
# 11088  [042940]              르네코                       매출액       3,496,379,739
# 11104  [058470]             리노공업                   수익(매출액)      26,574,818,407
# 11126  [039980]              리노스                       매출액      28,166,991,069
# 11161  [016100]          리더스코스메틱                       매출액      33,801,400,208
# 11182  [197210]               리드                       매출액       5,003,428,000
# 11203  [012700]             리드코프                     상품매출액      40,307,943,558
# 11204  [012700]             리드코프                     용역매출액       1,263,121,935
# 11231  [038340]               리젠                       매출액       4,653,203,025
# 11284  [042500]              링네트                       매출액      20,724,690,712
# 11304  [027740]              마니커                       매출액      55,048,211,764
# 11322  [098120]          마이크로컨텍솔                   수익(매출액)       5,740,302,897
# 11343  [035480]             마제스타                   수익(매출액)       7,689,691,162
# 11370  [038290]             마크로젠                   수익(매출액)      16,811,262,169
# 11391  [204320]               만도                       매출액     709,798,520,513
# 11412  [001080]             만호제강                   수익(매출액)      49,897,629,008
# 11443  [127160]           매직마이크로                   수익(매출액)      16,836,905,888
# 11462  [093520]              매커스                   수익(매출액)      12,389,878,620
# 11479  [141070]             맥스로텍                       매출액      12,948,177,057
# 11512  [072870]            메가스터디                       매출액       8,019,909,534
# 11536  [215200]          메가스터디교육                   수익(매출액)      39,430,231,416
# 11553  [133750]             메가엠디                       매출액      16,802,395,391
# 11586  [086900]             메디톡스                       매출액      25,627,554,849
# 11608  [078160]            메디포스트                   수익(매출액)       8,042,960,685
# 11632  [065650]             메디프론                       매출액       2,304,266,428
# 11695  [058110]           멕아이씨에스                       매출액       1,653,786,357
# 11763  [096640]              멜파스                       매출액      24,874,085,783
# 11783  [017180]             명문제약                   수익(매출액)      32,259,284,565
# 11802  [012690]             모나리자                       매출액      32,445,239,512
# 11825  [005360]              모나미                   수익(매출액)      28,323,265,268
# 11826  [005360]              모나미                     상품매출액      27,941,398,254
# 11827  [005360]              모나미                 기타수익(매출액)         413,533,680
# 11849  [149940]           모다정보통신                   수익(매출액)       9,621,953,278
# 11870  [080160]             모두투어                       매출액      53,119,791,339
# 11895  [100030]            모바일리더                       매출액       1,231,529,282
# 11914  [101330]             모베이스                   수익(매출액)       8,236,237,373
# 11930  [033200]              모아텍                       매출액      17,248,564,278
# 11962  [006920]              모헨즈                   수익(매출액)       7,301,832,443
# 11978  [009580]            무림P&P                       매출액     160,431,763,303
# 12007  [001810]             무림SP                       매출액      33,096,028,490
# 12027  [009200]            무림페이퍼                       매출액     149,891,179,126
# 12067  [008420]             문배철강                       매출액      29,361,433,461
# 12090  [161570]           미동앤씨네마                       매출액       6,787,132,811
# 12112  [095500]            미래나노텍                       매출액      45,132,914,997
# 12133  [025560]             미래산업                   수익(매출액)       5,925,213,982
# 12149  [007120]           미래아이앤지                       매출액       1,708,018,361
# 12199  [049950]            미래컴퍼니                   수익(매출액)      18,412,950,000
# 12217  [213090]          미래테크놀로지                   수익(매출액)       5,305,993,021
# 12254  [002840]             미원상사                       매출액      41,912,653,533
# 12255  [002840]             미원상사                     제품매출액      32,526,482,084
# 12256  [002840]             미원상사                    원재료매출액       9,225,306,216
# 12257  [002840]             미원상사                     용역매출액         160,865,233
# 12326  [107590]            미원에스씨                       매출액      71,013,439,821
# 12327  [107590]            미원에스씨                     제품매출액      69,432,898,014
# 12328  [107590]            미원에스씨                    원재료매출액       1,580,541,807
# 12391  [134380]             미원화학                     제품매출액      32,512,026,434
# 12392  [134380]             미원화학                    원재료매출액       3,328,794,865
# 12480  [059090]               미코                       매출액      10,924,403,227
# 12567  [206640]            바디텍메드                       매출액       9,579,939,482
# 12585  [018700]              바른손                       매출액       1,854,537,513
# 12641  [064520]             바른전자                   수익(매출액)      53,125,433,718
# 12674  [029480]         바른테크놀로지                        매출액       6,361,761,928
# 12697  [053030]             바이넥스                       매출액      19,906,692,371
# 12725  [084990]            바이로메드                   수익(매출액)         565,986,398
# 12745  [064550]            바이오니아                       매출액       4,339,612,663
# 12766  [052260]            바이오랜드                   수익(매출액)      24,181,516,345
# 12789  [208710]        바이오로그디바이스                       매출액      15,505,387,418
# 12805  [038460]           바이오스마트                   수익(매출액)       9,513,770,967
# 12825  [086040]           바이오톡스텍                   수익(매출액)       4,095,363,651
# 12828  [086040]           바이오톡스텍                 기타수익(매출액)         409,253,816
# 12892  [032980]              바이온                       매출액       3,705,853,293
# 12910  [043150]               바텍                       매출액      24,627,917,046
# 12929  [003610]               방림                       매출액      28,377,563,658
# 12953  [001340]             백광산업                   수익(매출액)      38,019,099,793
# 12983  [014580]             백광소재                       매출액      28,303,857,228
# 13008  [046310]            백금T&A                       매출액       8,503,649,557
# 13026  [035150]               백산                       매출액      46,508,536,221
# 13048  [036620]             버추얼텍                   수익(매출액)       2,282,467,250
# 13081  [002410]             범양건영                     Ⅰ.매출액      13,568,225,915
# 13106  [177350]               베셀                       매출액       7,136,015,188
# 13122  [007210]               벽산                   수익(매출액)      65,047,449,986
# 13142  [225530]             보광산업                   수익(매출액)      10,047,305,902
# 13167  [002760]               보락                       매출액       9,195,257,087
# 13187  [014100]           보령메디앙스                       매출액      32,306,103,559
# 13207  [003850]             보령제약                       매출액      88,857,566,569
# 13228  [004740]           보루네오가구                       매출액       8,802,350,929
# 13247  [006910]            보성파워텍                   수익(매출액)      14,930,433,610
# 13248  [006910]            보성파워텍           재화의판매로인한수익(매출액)      14,895,783,610
# 13249  [006910]            보성파워텍                 기타수익(매출액)          34,650,000
# 13309  [026260]            보타바이오                   수익(매출액)       2,004,471,319
# 13326  [000890]             보해양조                       매출액      34,143,971,659
# 13354  [026940]             부국철강                   수익(매출액)      35,463,530,524
# 13375  [014470]               부방                   수익(매출액)       2,693,849,609
# 13402  [025270]             부산방직                   수익(매출액)         967,944,760
# 13420  [011390]             부산산업                       매출액       7,195,304,686
# 13421  [011390]             부산산업                     제품매출액       7,179,758,686
# 13422  [011390]             부산산업                     상품매출액          15,546,000
# 13444  [005030]             부산주공                       매출액      47,446,498,863
# 13465  [008470]              부스타                   수익(매출액)      17,579,231,811
# 13466  [008470]              부스타           재화의판매로인한수익(매출액)       9,873,499,740
# 13467  [008470]              부스타          용역의제공으로인한수익(매출액)       7,705,732,071
# 13525  [100120]              뷰웍스                       매출액      23,709,293,626
# 13543  [064480]             브리지텍                   수익(매출액)       9,260,004,697
# 13561  [033560]              블루콤                   수익(매출액)      40,249,027,620
# 13579  [100220]             비상교육                       매출액      27,131,335,208
# 13597  [200780]           비씨월드제약                     I.매출액      10,337,264,013
# 13614  [141000]             비아트론                   수익(매출액)      12,123,030,620
# 13655  [083650]           비에이치아이                       매출액      61,974,434,638
# 13679  [086670]              비엠티                   수익(매출액)       9,391,609,824
# 13696  [082920]             비츠로셀                       매출액      23,790,952,610
# 13713  [054220]            비츠로시스                   수익(매출액)      16,771,641,592
# 13740  [042370]            비츠로테크                       매출액      23,831,293,371
# 13756  [032850]            비트컴퓨터                       매출액       8,463,655,693
# 13778  [093190]              빅솔론                       매출액      18,999,725,541
# 13815  [005180]              빙그레                       매출액     166,664,413,982
# 13854  [072950]             빛샘전자                   수익(매출액)       4,662,389,587
# 13874  [143240]          사람인에이치알                   수익(매출액)      18,001,295,647
# 13894  [003960]             사조대림                   수익(매출액)      99,284,496,515
# 13914  [008040]            사조동아원                   수익(매출액)      85,700,411,378
# 13979  [006090]             사조오양                       매출액      62,028,741,777
# 14002  [079660]             사조해표                       매출액     175,459,809,684
# 14022  [123260]        사파이어테크놀로지                       매출액       3,018,017,490
# 14042  [100090]            삼강엠앤티                       매출액      60,473,454,063
# 14061  [005090]            삼광글라스                       매출액      67,734,816,690
# 14104  [014970]             삼륭물산                       매출액       9,569,307,113
# 14105  [014970]             삼륭물산                     제품매출액       8,797,543,637
# 14106  [014970]             삼륭물산                     상품매출액                   0
# 14107  [014970]             삼륭물산                     임대매출액         771,763,476
# 14141  [018310]            삼목에스폼                   수익(매출액)      65,454,418,641
# 14161  [053700]            삼보모터스                       매출액      66,549,453,502
# 14186  [009620]             삼보산업                       매출액      70,061,060,972
# 14203  [023600]             삼보판지                       매출액      24,201,818,647
# 14204  [023600]             삼보판지                     제품매출액      23,150,196,682
# 14205  [023600]             삼보판지                     상품매출액         359,174,481
# 14206  [023600]             삼보판지                     기타매출액         692,447,484
# 14231  [111870]           삼본정밀전자                       매출액      11,614,506,363
# 14250  [001470]             삼부토건                   수익(매출액)      83,162,709,082
# 14251  [001470]             삼부토건           건설계약으로인한수익(매출액)      81,003,755,079
# 14252  [001470]             삼부토건           재화의판매로인한수익(매출액)       1,000,842,184
# 14253  [001470]             삼부토건          용역의제공으로인한수익(매출액)       1,158,111,819
# 14255  [001470]             삼부토건    건설계약으로인한수익(매출액)에대한매출원가      83,064,746,893
# 14256  [001470]             삼부토건    재화의판매로인한수익(매출액)에대한매출원가         839,312,142
# 14257  [001470]             삼부토건   용역의제공으로인한수익(매출액)에대한매출원가       1,016,135,231
# 14281  [006400]            삼성SDI                       매출액   1,057,776,989,730
# 14316  [006660]             삼성공조                       매출액      17,110,979,229
# 14339  [028260]             삼성물산                       매출액   4,559,672,268,780
# 14389  [009150]             삼성전기                       매출액   1,225,417,416,914
# 14425  [001360]             삼성제약                   수익(매출액)      10,064,240,699
# 14455  [068290]            삼성출판사                       매출액      12,041,930,282
# 14498  [009300]             삼아제약                       매출액      16,745,068,115
# 14521  [145990]              삼양사                       매출액     393,020,000,000
# 14543  [003230]             삼양식품                       매출액      75,703,757,755
# 14571  [000070]            삼양홀딩스                       매출액      50,721,000,000
# 14595  [002810]             삼영무역                       매출액      52,711,688,415
# 14596  [002810]             삼영무역                     상품매출액      52,253,459,532
# 14597  [002810]             삼영무역                     기타매출액         458,228,883
# 14625  [054540]             삼영엠텍                   수익(매출액)      10,611,092,996
# 14642  [065570]            삼영이엔씨                   수익(매출액)       7,733,103,583
# 14663  [005680]           삼영전자공업                       매출액      45,737,744,553
# 14683  [003720]           삼영화학공업                       매출액      23,022,640,543
# 14702  [082660]             삼우엠스                   수익(매출액)      15,349,950,937
# 14723  [023000]             삼원강재                       매출액      67,998,415,102
# 14745  [073640]             삼원테크                       매출액       6,369,025,018
# 14765  [004380]            삼익THK                       매출액      42,054,384,008
# 14789  [002450]             삼익악기                   수익(매출액)      39,316,319,216
# 14813  [032280]               삼일                   수익(매출액)      23,399,949,641
# 14833  [002290]           삼일기업공사                       매출액       9,758,571,067
# 14849  [000520]             삼일제약                       매출액      23,916,407,354
# 14870  [009770]             삼정펄프                   수익(매출액)      38,113,005,806
# 14871  [009770]             삼정펄프                     제품매출액      34,597,635,226
# 14872  [009770]             삼정펄프                  상품.기타매출액       3,515,370,580
# 14947  [037460]             삼지전자                       매출액       7,921,342,749
# 14971  [032750]               삼진                       매출액      17,657,040,742
# 15042  [054090]            삼진엘앤디                       매출액      22,989,755,925
# 15061  [005500]             삼진제약                   수익(매출액)      58,180,251,835
# 15100  [004690]              삼천리                       매출액     986,529,416,973
# 15101  [004690]              삼천리                     상품매출액     976,256,986,612
# 15102  [004690]              삼천리                     제품매출액       7,119,389,036
# 15103  [004690]              삼천리                     기타매출액       3,153,041,325
# 15128  [024950]           삼천리자전거                       매출액      30,194,254,144
# 15151  [017480]             삼현철강                   수익(매출액)      33,299,398,680
# 15180  [010960]             삼호개발                   수익(매출액)      60,776,611,045
# ...
# 34876  [035200]            프럼파스트                   수익(매출액)       7,414,759,504
# 34877  [035200]            프럼파스트           재화의판매로인한수익(매출액)       7,342,594,064
# 34878  [035200]            프럼파스트          용역의제공으로인한수익(매출액)          72,165,440
# 34880  [035200]            프럼파스트    재화의판매로인한수익(매출액)에대한매출원가       6,023,324,988
# 34881  [035200]            프럼파스트   용역의제공으로인한수익(매출액)에대한매출원가         124,177,636
# 34932  [203690]           프로스테믹스                   수익(매출액)       3,292,515,975
# 34953  [053610]              프로텍                       매출액      19,413,806,834
# 34991  [060910]              프리젠                       매출액         480,261,549
# 35015  [023770]            플레이위드                       매출액       2,358,637,693
# 35052  [051380]            피씨디렉트                   수익(매출액)      54,996,780,443
# 35072  [131390]           피앤이솔루션                       매출액       6,633,158,695
# 35094  [024850]            피에스엠씨                       매출액       4,388,642,554
# 35112  [031980]            피에스케이                   수익(매출액)      20,746,948,067
# 35136  [002230]             피에스텍                   수익(매출액)      11,615,780,145
# 35158  [137400]              피엔티                   수익(매출액)      16,247,816,449
# 35217  [128660]            피제이메탈                       매출액      17,086,786,909
# 35237  [006140]            피제이전자                   수익(매출액)      24,310,575,912
# 35259  [087600]            픽셀플러스                   수익(매출액)      20,121,813,299
# 35281  [033180]              필룩스                     I.매출액      11,822,111,848
# 35301  [064800]              필링크                   수익(매출액)       3,320,916,982
# 35444  [136480]               하림                       매출액     168,251,569,382
# 35660  [126700]          하이비젼시스템                       매출액      14,166,677,909
# 35677  [200470]              하이셈                   수익(매출액)       3,423,651,188
# 35696  [106080]             하이소닉                   수익(매출액)       8,382,804,747
# 35714  [071090]             하이스틸                       매출액      32,762,644,883
# 35736  [066980]              하이쎌                       매출액       2,051,853,044
# 35758  [221840]            하이즈항공                       매출액       7,140,062,157
# 35777  [106190]             하이텍팜                   수익(매출액)      15,280,174,550
# 35801  [019490]         하이트론씨스템즈                       매출액       8,841,983,294
# 35802  [019490]         하이트론씨스템즈                     상품매출액       2,146,510,156
# 35803  [019490]         하이트론씨스템즈                     제품매출액       6,695,473,138
# 35864  [000080]            하이트진로                   수익(매출액)     353,358,132,663
# 35884  [000140]         하이트진로홀딩스                   수익(매출액)      40,256,243,606
# 35903  [066130]               하츠                     Ⅰ.매출액      17,466,133,028
# 35927  [004590]             한국가구                       매출액       2,442,564,578
# 35945  [036460]           한국가스공사                   수익(매출액)   7,612,305,435,903
# 35946  [036460]           한국가스공사           재화의판매로인한수익(매출액)   7,599,875,144,555
# 35947  [036460]           한국가스공사              정부보조금수익(매출액)         603,134,794
# 35948  [036460]           한국가스공사                 기타수익(매출액)      11,827,156,554
# 35950  [036460]           한국가스공사    재화의판매로인한수익(매출액)에대한매출원가   6,624,518,068,288
# 35951  [036460]           한국가스공사          기타수익(매출액)에대한매출원가       3,885,673,259
# 36043  [005430]             한국공항                   수익(매출액)     109,352,013,546
# 36044  [005430]             한국공항                     상품매출액       3,223,157,194
# 36080  [034950]           한국기업평가                   수익(매출액)       9,629,317,367
# 36100  [010040]             한국내화                       매출액      59,318,098,351
# 36125  [025540]           한국단자공업                       매출액     161,214,693,228
# 36167  [004090]           한국석유공업                       매출액      37,329,548,754
# 36189  [025550]             한국선재                       매출액      28,861,304,273
# 36214  [002200]         한국수출포장공업                   수익(매출액)      52,983,335,068
# 36231  [002960]            한국쉘석유                       매출액      53,545,881,665
# 36260  [002000]           한국유리공업                       매출액      49,811,372,333
# 36307  [015760]           한국전력공사                       매출액  15,566,139,000,000
# 36308  [015760]           한국전력공사               재화의판매로인한매출액  14,485,653,000,000
# 36309  [015760]           한국전력공사              용역의제공으로인한매출액      42,490,000,000
# 36310  [015760]           한국전력공사               건설계약으로인한매출액     940,078,000,000
# 36380  [006200]          한국전자홀딩스                       매출액       2,415,178,901
# 36400  [101680]           한국정밀기계                   수익(매출액)       3,464,621,285
# 36423  [039740]           한국정보공학                       매출액      25,288,881,588
# 36481  [025770]           한국정보통신                       매출액      77,025,447,000
# 36482  [025770]           한국정보통신                     상품매출액       2,971,310,000
# 36483  [025770]           한국정보통신                     용역매출액      74,054,137,000
# 36503  [002300]             한국제지                       매출액     130,002,046,960
# 36533  [025890]             한국주강                   수익(매출액)       7,379,325,608
# 36555  [000970]          한국주철관공업                       매출액      26,891,004,339
# 36583  [017960]             한국카본                   수익(매출액)      57,162,951,247
# 36604  [054040]            한국컴퓨터                       매출액      59,003,973,512
# 36626  [161890]             한국콜마                       매출액     144,536,092,385
# 36666  [021650]             한국큐빅                   수익(매출액)       3,708,256,255
# 36695  [161390]            한국타이어                   수익(매출액)     811,920,972,198
# 36731  [053590]          한국테크놀로지                   수익(매출액)         646,175,184
# 36761  [037230]            한국팩키지                       매출액      14,104,308,948
# 36779  [010100]          한국프랜지공업                   수익(매출액)     215,551,259,710
# 36780  [010100]          한국프랜지공업           재화의판매로인한수익(매출액)     215,551,259,710
# 36782  [010100]          한국프랜지공업    재화의판매로인한수익(매출액)에대한매출원가     207,111,999,047
# 36801  [047810]           한국항공우주                   수익(매출액)     710,595,000,000
# 36824  [123690]            한국화장품                       매출액       6,317,029,276
# 36845  [003350]          한국화장품제조                       매출액      13,280,146,955
# 36867  [030520]           한글과컴퓨터                       매출액      22,959,797,626
# 36887  [052600]              한네트                     Ⅰ.매출액       6,877,089,108
# 36909  [011500]             한농화성                   수익(매출액)      47,534,275,594
# 36934  [014790]               한라                       매출액     306,233,305,956
# 36962  [092460]            한라IMS                   수익(매출액)      11,052,297,533
# 36981  [060980]            한라홀딩스                       매출액     147,639,795,513
# 37006  [053690]            한미글로벌                   수익(매출액)      26,601,066,381
# 37031  [042700]            한미반도체                       매출액      51,590,994,692
# 37057  [008930]           한미사이언스                   수익(매출액)      22,241,147,025
# 37106  [128940]             한미약품                       매출액     195,447,087,764
# 37138  [047080]            한빛소프트                       매출액       6,731,199,281
# 37159  [009240]               한샘                       매출액     417,060,207,215
# 37179  [020000]               한섬                       매출액     173,180,728,736
# 37201  [003680]             한성기업                       매출액      62,822,175,528
# 37232  [105630]             한세실업                   수익(매출액)     354,187,192,995
# 37274  [081970]            한솔넥스지                   수익(매출액)       5,038,438,659
# 37294  [009180]          한솔로지스틱스                       매출액      91,976,013,342
# 37328  [221610]            한솔씨앤피                       매출액      11,082,889,951
# 37355  [007190]          한솔아트원제지                   수익(매출액)      88,338,264,877
# 37396  [070590]           한솔인티큐브                   수익(매출액)      10,832,212,978
# 37427  [213500]             한솔제지                       매출액     354,282,422,102
# 37447  [014680]            한솔케미칼                       매출액      77,463,060,066
# 37448  [014680]            한솔케미칼                     상품매출액       3,561,293,190
# 37449  [014680]            한솔케미칼                     제품매출액      73,879,023,517
# 37450  [014680]            한솔케미칼                     기타매출액          22,743,359
# 37478  [004710]           한솔테크닉스                   수익(매출액)     112,354,225,056
# 37500  [010420]           한솔피엔에스                   수익(매출액)      60,828,430,252
# 37569  [025750]            한솔홈데코                   수익(매출액)      53,234,022,164
# 37590  [042520]          한스바이오메드                       매출액       8,798,030,054
# 37611  [004960]             한신공영                   수익(매출액)     371,614,573,517
# 37635  [011700]           한신기계공업                       매출액      12,292,297,953
# 37657  [078350]            한양디지텍                   수익(매출액)      27,999,148,433
# 37679  [045100]            한양이엔지                   수익(매출액)      82,441,219,580
# 37700  [064090]           한양하이타오                   수익(매출액)       4,306,184,091
# 37724  [009420]          한올바이오파마                     I.매출액      21,634,953,527
# 37742  [014130]           한익스프레스                       매출액     108,335,275,691
# 37763  [046110]           한일네트웍스                       매출액      17,646,167,861
# 37791  [005860]             한일사료                   수익(매출액)      25,932,450,758
# 37792  [005860]             한일사료           재화의판매로인한수익(매출액)      25,910,585,561
# 37793  [005860]             한일사료                 기타수익(매출액)          21,865,197
# 37795  [005860]             한일사료    재화의판매로인한수익(매출액)에대한매출원가      21,706,972,074
# 37796  [005860]             한일사료          기타수익(매출액)에대한매출원가          27,404,165
# 37823  [123840]             한일진공                       매출액       3,666,676,898
# 37847  [002220]             한일철강                       매출액      22,184,581,078
# 37867  [007770]             한일화학                   수익(매출액)      19,745,142,424
# 37887  [051600]            한전KPS                       매출액     247,144,990,649
# 37908  [052690]             한전기술                       매출액     117,984,470,284
# 37942  [002320]               한진                   매출액(수익)     393,095,547,370
# 37981  [180640]              한진칼                 영업수익(매출액)      31,170,051,659
# 38001  [061460]            한진피앤씨                   수익(매출액)      21,962,851,990
# 38023  [117930]             한진해운                       매출액   1,574,612,571,696
# 38057  [005110]               한창                   수익(매출액)       1,986,031,958
# 38058  [005110]               한창                     상품매출액       1,749,211,000
# 38060  [005110]               한창                     기타매출액          52,065,897
# 38128  [079170]             한창산업                   수익(매출액)       9,940,878,922
# 38149  [009460]             한창제지                       매출액      50,364,593,013
# 38172  [054920]            한컴시큐어                   수익(매출액)       3,193,335,422
# 38193  [077280]            한컴지엠디                       매출액       1,477,999,267
# 38210  [002680]               한탑                       매출액      21,926,867,332
# 38231  [066110]               한프                   수익(매출액)       4,510,392,505
# 38253  [000880]               한화                     Ⅰ.매출액   1,160,606,000,000
# 38273  [027390]       한화갤러리아타임월드                   수익(매출액)      57,495,008,763
# 38297  [009830]            한화케미칼                       매출액     780,701,735,195
# 38320  [012450]            한화테크윈                   수익(매출액)     599,872,119,603
# 38358  [102210]           해덕파워웨이                   수익(매출액)      21,196,928,634
# 38403  [076610]            해성옵틱스                       매출액      85,808,006,426
# 38428  [101530]           해태제과식품                       매출액     180,525,026,531
# 38460  [000720]             현대건설                       매출액   2,443,824,000,000
# 38482  [170030]             현대공업                   수익(매출액)      32,155,974,319
# 38506  [005440]           현대그린푸드                   수익(매출액)     406,608,904,000
# 38537  [064350]             현대로템                       매출액     669,129,597,000
# 38562  [079430]            현대리바트                   수익(매출액)     168,593,267,176
# 38590  [010620]           현대미포조선                       매출액     912,898,465,000
# 38619  [004560]          현대비앤지스틸                       매출액     155,287,386,912
# 38657  [011200]             현대상선                       매출액   1,160,838,000,000
# 38686  [006390]            현대시멘트                       매출액      78,072,973,767
# 38713  [048410]           현대아이비티                   수익(매출액)       7,110,125,496
# 38714  [048410]           현대아이비티                     제품매출액       6,398,489,386
# 38715  [048410]           현대아이비티                     상품매출액         356,750,630
# 38716  [048410]           현대아이비티                     기타매출액         354,885,480
# 38783  [004310]             현대약품                       매출액      27,733,410,394
# 38804  [126560]          현대에이치씨엔                   수익(매출액)      10,164,180,225
# 38826  [017800]          현대엘리베이터                       매출액     320,473,986,239
# 38845  [011210]             현대위아                       매출액   1,773,333,236,962
# 38877  [026180]           현대정보기술                       매출액      40,997,036,642
# 38900  [004020]             현대제철                       매출액   3,203,967,760,871
# 38932  [009540]            현대중공업                       매출액   5,554,388,789,000
# 38953  [039010]             현대통신                   수익(매출액)      19,570,076,059
# 38975  [011720]            현대페인트                   수익(매출액)       7,042,487,172
# 38994  [057050]            현대홈쇼핑                       매출액     232,721,610,289
# 39014  [092300]             현우산업                   수익(매출액)      31,097,146,433
# 39030  [053660]             현진소재                   수익(매출액)      50,360,413,693
# 39066  [011080]            형지I&C                   수익(매출액)                 NaN
# 39087  [093240]            형지엘리트                   수익(매출액)      14,200,803,984
# 39134  [060560]              홈센타                   수익(매출액)      11,495,875,470
# 39166  [039610]               화성                       매출액      12,966,553,896
# 39187  [002460]             화성산업                       매출액     102,299,417,494
# 39218  [013520]           화승알앤에이                       매출액     183,788,791,273
# 39249  [010690]               화신                   수익(매출액)     130,553,680,180
# 39278  [126640]             화신정공                       매출액      49,574,694,384
# 39305  [086250]             화신테크                       매출액       9,134,909,358
# 39319  [204630]           화이브라더스                       매출액       5,455,452,272
# 39338  [133820]            화인베스틸                       매출액      42,680,589,742
# 39381  [134780]               화진                   수익(매출액)      19,933,091,302
# 39409  [000850]             화천기공                       매출액      40,252,172,944
# 39431  [016580]             환인제약                       매출액      34,992,067,407
# 39450  [032560]            황금에스티                       매출액      27,791,351,463
# 39467  [004800]               효성                   수익(매출액)   1,891,363,638,579
# 39490  [094280]           효성 ITX                       매출액      72,984,376,594
# 39512  [097870]            효성오앤비                       매출액       3,292,727,055
# 39528  [093370]               후성                       매출액      54,610,819,002
# 39576  [005870]        휴니드테크놀러지스                   수익(매출액)      14,019,534,132
# 39594  [051980]              휴림스                       매출액       3,729,201,940
# 39614  [115160]              휴맥스                       매출액     193,320,200,591
# 39664  [200670]             휴메딕스                   매출액(수익)      10,714,365,696
# 39688  [079980]              휴비스                   수익(매출액)     215,511,155,880
# 39711  [065510]              휴비츠                       매출액      15,755,339,526
# 39732  [005010]              휴스틸                       매출액      84,536,301,390
# 39754  [084110]              휴온스                       매출액          91,258,867
# 39802  [069260]              휴켐스                   수익(매출액)     135,619,442,531
# 39822  [024060]             흥구석유                       매출액      35,160,812,424
# 39838  [010240]               흥국                       매출액      12,630,111,930
# 39858  [189980]           흥국에프엔비                   수익(매출액)       7,740,104,511
# 39876  [003280]             흥아해운                       매출액     196,967,255,035
# 39900  [037440]               희림                       매출액      32,954,589,235

# %%
df1[df1<5]
# Out:
# 회사명
# 나스미디어    4
# 농우바이오    4
# 디에이피     4
# 세명전기     4
# 티엘아이     4
# dtype: int64

# %%
### <font color = "#DAF7A5"> Values ?

# %% [markdown]
# ### <font color = "#DAF7A5"> imputation ?

# %%
df['항목명'].unique()
# Out:
# array(['수익(매출액)', '매출원가', '매출총이익', ..., '순금융수익(비용)', '외환수익', '외환비용'],
#       dtype=object)

# %%
df.loc[df['회사명'] == '엠제이비']
# Out:
#            종목코드   회사명                 항목명              당기              전기
# 22874  [074150]  엠제이비                 매출액   4,444,328,376   5,744,391,048
# 22875  [074150]  엠제이비                제품매출     110,214,780     506,801,130
# 22876  [074150]  엠제이비                상품매출     330,000,000       2,500,000
# 22877  [074150]  엠제이비                공사매출             NaN   3,558,974,000
# 22878  [074150]  엠제이비                용역매출   2,875,900,000     595,466,647
# ...         ...   ...                 ...             ...             ...
# 22971  [074150]  엠제이비        매도가능금융자산평가손익     -51,811,584      57,798,834
# 22972  [074150]  엠제이비           총포괄이익(손실)  -5,565,062,668  14,792,368,547
# 22973  [074150]  엠제이비                주당손익             NaN             NaN
# 22974  [074150]  엠제이비         기본주당순이익(손실)            -202             660
# 22975  [074150]  엠제이비         희석주당순이익(손실)            -154             660
#
# [102 rows x 5 columns]

# %%
df.loc[df['회사명'] == '나스미디어']
# Out:
#           종목코드    회사명               항목명             당기             전기
# 5025  [089600]  나스미디어         당기순이익(손실)  9,916,023,522  7,956,450,620
# 5026  [089600]  나스미디어    법인세비용차감후기타포괄손익   -562,911,063   -181,541,271
# 5027  [089600]  나스미디어     확정급여제도의 재측정손익   -562,911,063   -181,541,271
# 5028  [089600]  나스미디어             총포괄손익  9,353,112,459  7,774,909,349

# %%
df.회사명.unique()
# Out:
# array(['3S', 'AJ네트웍스', 'AJ렌터카', ..., '흥국에프엔비', '흥아해운', '희림'], dtype=object)

# %%
df.loc[df['회사명'] == 'AJ네트웍스']
# Out:
#                                 재무제표종류      종목코드     회사명        시장구분   업종  \
# 17  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 18  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 19  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 20  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 21  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 22  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 23  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 24  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 25  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 26  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 27  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 28  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 29  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 30  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 31  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 32  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 33  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 34  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 35  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
# 36  포괄손익계산서, 기능별 분류(세후기타포괄손익) - 별도재무제표  [095570]  AJ네트웍스  유가증권시장상장법인  693
#
#                 업종명  결산월       결산기준일  보고서종류   통화  \
# 17  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 18  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 19  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 20  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 21  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 22  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 23  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 24  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 25  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 26  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 27  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 28  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 29  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 30  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 31  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 32  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 33  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 34  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 35  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
# 36  산업용 기계 및 장비 임대업   12  12/31/2015  사업보고서  KRW
#
#                                                  항목코드  \
# 17                                       ifrs_Revenue
# 18                                   ifrs_CostOfSales
# 19  entity00365387_udf_IS_201632916234426_Statemen...
# 20                                    dart_OtherGains
# 21                                   dart_OtherLosses
# 22  ifrs_OtherIncomeExpenseFromSubsidiariesJointly...
# 23                                 ifrs_FinanceIncome
# 24                                  ifrs_FinanceCosts
# 25                           ifrs_ProfitLossBeforeTax
# 26          ifrs_IncomeTaxExpenseContinuingOperations
# 27                                    ifrs_ProfitLoss
# 28                      ifrs_OtherComprehensiveIncome
# 29  entity00365387_udf_IS_2015330133713201_OtherCo...
# 30  entity00365387_udf_IS_2015330133719939_OtherCo...
# 31  entity00365387_udf_IS_2015330133724286_OtherCo...
# 32  entity00365387_udf_IS_201533013373529_OtherCom...
# 33                           ifrs_ComprehensiveIncome
# 34                      ifrs_EarningsPerShareAbstract
# 35                     ifrs_BasicEarningsLossPerShare
# 36                   ifrs_DilutedEarningsLossPerShare
#
#                               항목명               당기               전기  \
# 17                           영업수익  196,520,251,563  194,184,554,953
# 18                           영업비용  172,850,127,896  167,898,839,204
# 19                           영업이익   23,670,123,667   26,285,715,749
# 20                           기타수익      932,498,291      422,639,674
# 21                           기타비용    1,275,249,854    2,383,228,451
# 22                       종속기업투자손익   10,649,806,631   10,483,493,695
# 23                           금융수익      757,796,302    1,747,232,809
# 24                           금융비용   12,607,433,619   15,407,947,467
# 25                    법인세비용차감전순이익   22,127,541,418   21,147,906,009
# 26                          법인세비용    3,042,950,494    2,686,422,075
# 27                      당기순이익(손실)   19,084,590,924   18,461,483,934
# 28                         기타포괄손익       98,240,680      -98,391,420
# 29     후속적으로 당기손익으로 재분류 될 수 있는 항목              NaN              NaN
# 30                       지분법 자본변동       -9,054,954     -117,750,518
# 31                   매도가능금융자산평가손익       73,342,866       20,344,802
# 32                   파생상품평가(이익)손실       33,952,768         -985,704
# 33                         당기포괄이익   19,182,831,604   18,363,092,514
# 34                주당이익 [abstract]              NaN              NaN
# 35                         기본주당이익            2,424            3,046
# 36                         희석주당이익            2,424            3,046
#
#                전전기
# 17  20,707,731,342
# 18   3,869,129,747
# 19  16,838,601,595
# 20      28,550,726
# 21   6,197,028,713
# 22             NaN
# 23     583,928,814
# 24   4,023,874,050
# 25   7,230,178,372
# 26     943,732,437
# 27   6,286,445,935
# 28    -118,151,273
# 29             NaN
# 30    -144,768,773
# 31      26,617,500
# 32             NaN
# 33   6,168,294,662
# 34             NaN
# 35           2,522
# 36           2,522
