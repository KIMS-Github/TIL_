# %% [markdown]
# ### 2. 오설록 : Scrapy
#
#
# - 아래의 절차로 상품데이터를 수집하세요.
#     - 오설록 사이트의 전체상품 페이지에서 각 페이지 URL 크롤링
#         - 오설록 전체 상품 페이지 URL : https://www.osulloc.com/kr/ko/shop/item/list?category=teashop
#     - 각 상품 페이지 크롤링
#     - 상품의 상세 페이지 크롤링
#
# - 수집 데이터
#     - 상품명, 상품설명, 가격정보, 별점, 이미지링크, 상품링크
#     - title, desc, price, star, img, link

# %%
# 프로젝트 생성

# %%
# !rm -rf osulloc/

# %%
# !scrapy startproject osulloc
# Out:
# New Scrapy project 'osulloc', using template directory '/usr/local/anaconda3/lib/python3.7/site-packages/scrapy/templates/project', created in:
#     /Users/rada/Documents/lecture/dss/dss_13/quiz/04_crawling/osulloc
#
# You can start your first spider with:
#     cd osulloc
#     scrapy genspider example example.com

# %%
# 아이템 모델 코드 추가

# %%
# %%writefile osulloc/osulloc/items.py
import scrapy


class OsullocItem(scrapy.Item):
    title = scrapy.Field()
    desc = scrapy.Field()
    price = scrapy.Field()
    star = scrapy.Field()
    img = scrapy.Field()
    link = scrapy.Field()
# Out:
# Overwriting osulloc/osulloc/items.py

# %%
# 스파이더 코드 추가

# %%
# %%writefile osulloc/osulloc/spiders/spider.py

import scrapy
import requests

from osulloc.items import OsullocItem
from scrapy.http import TextResponse

class OsullocSpider(scrapy.Spider):
    
    name = "Osulloc"
    allow_domain = ["https://www.osulloc.com"]
    start_urls = ["https://www.osulloc.com/kr/ko/shop/item/list?category=teashop"]
    
    def parse(self, response):
        
        # 마지막 페이지 확인
        try:
            link = response.xpath('//*[@id="pagination"]/a[7]/@href')[0].extract()
            last_page = int(link.split("=")[-1])
        except:
            elements = response.xpath('//*[@id="pagination"]/a')
            last_page = len(elements)
        
        # 페이지별 링크 만들기
        for page in range(last_page + 1):
            link = response.url + "&p={}".format(page)
            yield scrapy.Request(link, callback=self.parse_page)
    
    # 각 상품별 상세 페이지 URL
    def parse_page(self, response):
        links = response.xpath('//*[@id="tag_search_item"]/div/a[1]/@href').extract()
        links = list(map(lambda data:response.urljoin(data), links))
        for link in links:
            yield scrapy.Request(link, callback=self.parse_page_contents)
          
    # 상세페이지에서 컨텐츠 가져오기            
    def parse_page_contents(self, response):
        item = OsullocItem()
        item["title"] = response.xpath('//*[@id="contents"]/div[1]/div[1]/div[2]/p[1]/text()')[0].extract()
        item["desc"] = response.xpath('//*[@id="onePointArea"]/text()')[0].extract()
        item["price"] = response.xpath('//*[@id="contents"]/div[1]/div[1]/div[2]/div[2]/div[2]/p/strong/text()')[0].extract()
        item["star"] = response.xpath('//*[@id="contents"]/div[1]/div[2]/div/div/span/text()')[0].extract()
        img = response.xpath('//*[@id="contents"]/div[1]/div[1]/div[1]/div/div[1]/img/@src')[0].extract()
        item["img"] = response.urljoin(img)
        item["link"] = response.url
        yield item
# Out:
# Writing osulloc/osulloc/spiders/spider.py

# %%
# 데이터 베이스 코드 추가

# %%
# %%writefile osulloc/osulloc/mongodb.py
import pymongo

client = pymongo.MongoClient('mongodb://rada:radapw@15.164.104.167:27017')
db = client.osulloc
collection = db.items
# Out:
# Writing osulloc/osulloc/mongodb.py

# %%
# 파이프라인 코드 추가

# %%
# %%writefile osulloc/osulloc/pipelines.py
from .mongodb import collection

class OsullocPipeline(object):

    def process_item(self, item, spider):

        # mongodb에 저장
        columns = ["title", "desc", "price", "star", "img", "link"]
        data = {column: item[column] for column in columns}
        collection.insert(data)

        return item
# Out:
# Overwriting osulloc/osulloc/pipelines.py

# %%
# 파이프 라인 설정

# %%
# !echo "ITEM_PIPELINES = {" >> osulloc/osulloc/settings.py

# %%
# !echo "   'osulloc.pipelines.OsullocPipeline': 300," >> osulloc/osulloc/settings.py

# %%
# !echo "}" >> osulloc/osulloc/settings.py

# %%
# !tail -n 3 osulloc/osulloc/settings.py
# Out:
# ITEM_PIPELINES = {
#    'osulloc.pipelines.OsullocPipeline': 300,
# }

# %%
# 코드의 실행

# %%
# teashop, bakery, themashop

# %%
# %%writefile run.sh
# cd osulloc
# scrapy crawl Osulloc -o osulloc_teashop.csv
# Out:
# Overwriting run.sh

# %%
# !rm osulloc/*.csv
# Out:
# rm: osulloc/*.csv: No such file or directory

# %%
# !source run.sh
# Out:
# 2020-07-08 08:20:29 [scrapy.utils.log] INFO: Scrapy 2.2.0 started (bot: osulloc)
# 2020-07-08 08:20:29 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 (default, Jan  8 2020, 13:42:34) - [Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1  11 Sep 2018), cryptography 2.8, Platform Darwin-19.4.0-x86_64-i386-64bit
# 2020-07-08 08:20:29 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-07-08 08:20:29 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'osulloc',
#  'NEWSPIDER_MODULE': 'osulloc.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['osulloc.spiders']}
# 2020-07-08 08:20:29 [scrapy.extensions.telnet] INFO: Telnet Password: c47503f8e5271536
# 2020-07-08 08:20:29 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-07-08 08:20:29 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-07-08 08:20:29 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-07-08 08:20:29 [scrapy.middleware] INFO: Enabled item pipelines:
# ['osulloc.pipelines.OsullocPipeline']
# 2020-07-08 08:20:29 [scrapy.core.engine] INFO: Spider opened
# 2020-07-08 08:20:29 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-07-08 08:20:29 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-07-08 08:20:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/robots.txt> (referer: None)
# 2020-07-08 08:20:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/list?category=teashop> (referer: None)
# 2020-07-08 08:20:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=6> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop)
# 2020-07-08 08:20:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop)
# 2020-07-08 08:20:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop)
# 2020-07-08 08:20:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop)
# 2020-07-08 08:20:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop)
# 2020-07-08 08:20:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop)
# 2020-07-08 08:20:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop)
# 2020-07-08 08:20:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17826> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=6)
# 2020-07-08 08:20:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17826>
# {'desc': '#Daily Energy 맑은 매일의 몸 컨디션을 위한 습관 형성에 도움을 주는 워터플러스 해피자몽과 제주 벚꽃 텀블러 '
#          '구성 세트',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/IS/UG/20200622160424352NX.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17826',
#  'price': '15,750',
#  'star': '0.0',
#  'title': '내일 더 생기넘치는 습관 세트 '}
# 2020-07-08 08:20:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16227> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=6)
# 2020-07-08 08:20:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16227>
# {'desc': '해당 제품은 단종되었습니다. 더 좋은 제품으로 찾아뵙겠습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/BI/UO/20200213095130432MQ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16227',
#  'price': '19,500',
#  'star': '0.0',
#  'title': '굿나잇 허브차 보틀 세트'}
# 2020-07-08 08:20:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/17443> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=6)
# 2020-07-08 08:20:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16190> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=6)
# 2020-07-08 08:20:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/17443>
# {'desc': '해당 제품은 단종되었습니다. 더 좋은 제품으로 찾아뵙겠습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/QC/XW/20200311154832034ZX.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/17443',
#  'price': '27,000',
#  'star': '0.0',
#  'title': '몽글몽글 밀크티(삼다연, 그린티)'}
# 2020-07-08 08:20:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/1461> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:20:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16190>
# {'desc': '휴대성이 좋은 달빛걷기 이미지의 오설록 보틀과 함께 언제 어디서나 쉽고 간편하게 시원한 녹차를 즐기세요.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/US/WA/20200706095528825NT.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16190',
#  'price': '10,000',
#  'star': '0.0',
#  'title': '달빛보틀 + 찬물녹차 20입(아이스티)'}
# 2020-07-08 08:20:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/1461>
# {'desc': '즐겁고 행복한 티타임을 선사하는 달콤하고 향긋한 오설록만의 특별한 블렌디드 티 선물세트 입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/PM/FK/20180510132548266RY.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/1461',
#  'price': '20,000',
#  'star': '4.6',
#  'title': '러블리티박스'}
# 2020-07-08 08:20:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16343> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=6)
# 2020-07-08 08:20:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16344> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=6)
# 2020-07-08 08:20:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16709> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:20:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16703> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=6)
# 2020-07-08 08:20:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16343>
# {'desc': '해당 제품은 단종되었습니다. 더 좋은 제품으로 찾아뵙겠습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/JX/UB/20190919202229970PT.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16343',
#  'price': '15,000',
#  'star': '4.8',
#  'title': '국화차 10입(피라미드)'}
# 2020-07-08 08:20:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16344>
# {'desc': '해당 제품은 단종되었습니다. 더 좋은 제품으로 찾아뵙겠습니다.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/AB/YR/20191014204836186EW.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16344',
#  'price': '40,000',
#  'star': '4.8',
#  'title': '국화차 40g(잎차)'}
# 2020-07-08 08:20:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16709>
# {'desc': '제주 삼나무의 그윽한 풍미에 제주영귤의 싱그러움을 더한 후발효차를 고급스러운 지함에 담았습니다. 소중한 사람에게 '
#          '선물해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/LZ/GT/20191017180759959NI.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16709',
#  'price': '12,000',
#  'star': '4.8',
#  'title': '삼다연제주영귤 10입(피라미드)'}
# 2020-07-08 08:20:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16703>
# {'desc': '가을이 깊어가는 시기에 피어난 향이 진한 국내산 국화로 만든 화차를 피라미드 티백으로 간편하게, 합리적인 가격으로 '
#          '즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/VH/MD/20191017180111961AR.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16703',
#  'price': '23,000',
#  'star': '4.9',
#  'title': '국화차 20입(피라미드)'}
# 2020-07-08 08:20:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16968> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:20:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16968>
# {'desc': '달큰한 배향이 달빛처럼 은은하게 감도는 후발효차를 소중한 사람에게 선물해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/SW/LS/20191216151128674DO.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16968',
#  'price': '15,000',
#  'star': '4.9',
#  'title': '달빛걷기 10입(피라미드)'}
# 2020-07-08 08:20:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16978> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:20:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16978>
# {'desc': '오설록 시그니처 발효차 삼다연 베이스의 오리지널 밀크티입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/FA/YT/20191216160219867FY.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16978',
#  'price': '9,600',
#  'star': '4.7',
#  'title': '삼다연오리지널밀크티 10입'}
# 2020-07-08 08:20:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17003> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:20:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16646> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:20:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16975> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16980> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:20:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/5764> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:20:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/14123> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:20:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17003>
# {'desc': '어린 찻잎을 정성껏 갈아 만든 깊은 풍미의 유기농 말차\r\n\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/ZP/EV/20191217181023859TD.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17003',
#  'price': '23,000',
#  'star': '4.8',
#  'title': '프리미엄 말차 40g'}
# 2020-07-08 08:20:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16646>
# {'desc': '깨끗한 제주의 신선한 찻잎을 정성스레 덖은 녹차입니다. 부담없는 가격으로 오설록의 녹차를 즐길 수 있습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/NS/QP/20191007152144573YX.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16646',
#  'price': '15,000',
#  'star': '4.7',
#  'title': '덖음차 50 g(잎차)'}
# 2020-07-08 08:20:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16975>
# {'desc': '애플시나몬향이 비 내린 숲처럼 신비롭게 녹아든 오리엔탈 블렌디드티를 소중한 사람에게 선물해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/XR/NJ/20191216155336513IC.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16975',
#  'price': '12,000',
#  'star': '4.8',
#  'title': '비의사색 10입(피라미드)'}
# 2020-07-08 08:20:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16980>
# {'desc': '녹차의 깊은 풍미를 두배 더한 더블샷 라떼입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/WM/NB/20191216160850911BY.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16980',
#  'price': '12,000',
#  'star': '4.5',
#  'title': '그린티라떼더블샷 10입'}
# 2020-07-08 08:20:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/6186> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/5764>
# {'desc': '차 향기와 함께, 비밀스러운 세계 여행 이야기가 펼쳐지는 티 모음 세트입니다. 9가지의 차를 다양하게 즐길 수 있는 '
#          '세트입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/WG/AK/20170525143048972GN.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/5764',
#  'price': '45,000',
#  'star': '4.8',
#  'title': '시크릿티스토리'}
# 2020-07-08 08:20:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/14123>
# {'desc': '마스터의 블렌딩으로 탄생한 오설록만의 제주의 향기를 담은 대표 블렌디드 티 모음 세트 입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/RB/SP/20170418183503104KB.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/14123',
#  'price': '50,000',
#  'star': '4.7',
#  'title': '마스터블렌드'}
# 2020-07-08 08:20:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/6186>
# {'desc': '제주 햇살 받고 자란 싱그러운 제주 영귤 아이스티입니다. 찬물에도 잘 우러나와 간편하게 즐기실 수 있습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/EJ/IH/20180716000029904BC.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/6186',
#  'price': '8,400',
#  'star': '4.8',
#  'title': '영귤섬 20입(아이스티)'}
# 2020-07-08 08:20:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/15083> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/15083>
# {'desc': '녹차, 호지차 스프레드와 별도 포장이 필요 없는 고급 패키지로 구성된 쨈 2종 세트입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/SO/QD/20190704100911630UX.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/15083',
#  'price': '19,000',
#  'star': '4.5',
#  'title': '오설록의 고급 녹차쨈 세트'}
# 2020-07-08 08:20:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/15243> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/15243>
# {'desc': '제주 밤바다처럼 그윽하고, 달큰한 배향이 환상적인 블렌디드티입니다.  제주 차밭의 맛과 향을 가벼운 가격으로 즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/MM/TD/20180906153227885BX.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/15243',
#  'price': '8,500',
#  'star': '4.6',
#  'title': '삼다꿀배티 20입(티백)'}
# 2020-07-08 08:20:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/6189> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16963> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16944> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/6189>
# {'desc': '제주 여름밤의 시원함을 담은 배향 아이스티입니다. 찬물에도 잘 우러나와 간편하게 즐기실 수 있습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/CB/AH/20180716000118593EB.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/6189',
#  'price': '8,400',
#  'star': '4.4',
#  'title': '달빛섬 20입(아이스티)'}
# 2020-07-08 08:20:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/5662> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16963>
# {'desc': ' 햇살 가득 머금고 자란 유자향이 새콤상큼한 그린티\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/MV/HX/20191216142700441DT.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16963',
#  'price': '12,000',
#  'star': '4.8',
#  'title': '햇살언덕 10입(피라미드)'}
# 2020-07-08 08:20:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16944>
# {'desc': '제주 삼나무의 그윽한 풍미에 제주영귤의 싱그러움을 더한 후발효차를 원하는 용량만큼 우려드실 수 있는 잎차입니다. 합리적인 '
#          '가격에 즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/AY/EO/20191213161207609NY.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16944',
#  'price': '15,000',
#  'star': '4.7',
#  'title': '삼다연제주영귤 30 g(잎차)'}
# 2020-07-08 08:20:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/15203> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/5662>
# {'desc': '제주 삼나무의 그윽한 풍미에 싱그러운 영귤의 상큼함이 매력적인 블렌디드 티입니다. 제주 차밭의 맛과 향을 가벼운 가격으로 '
#          '즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/KQ/WI/20160829162627548VB.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/5662',
#  'price': '8,500',
#  'star': '4.5',
#  'title': '제주삼다영귤티 20입(티백)'}
# 2020-07-08 08:20:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16970> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/15203>
# {'desc': '오설록의 블렌디드 티 중에서 가장 인기있는 제품 5가지를 모았습니다. 1개 제품의 가격으로 5가지의 다양한 과일향 티를 '
#          '즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/VB/BA/20191119162501347IG.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/15203',
#  'price': '13,000',
#  'star': '4.8',
#  'title': '블렌디드 컬렉션 5종'}
# 2020-07-08 08:20:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16970>
# {'desc': '제주 동백꽃향과 열대과일의 달콤한 풍미가 매력적인 블렌디드티를 소중한 사람에게 선물해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/ZG/JL/20191216152421407JO.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16970',
#  'price': '12,000',
#  'star': '4.8',
#  'title': '동백이피는곶자왈 10입(피라미드)'}
# 2020-07-08 08:20:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16345> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16345>
# {'desc': '상쾌하고 맑은 기운을 전하는 건강차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/GA/WE/20190919202512472DZ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16345',
#  'price': '12,000',
#  'star': '4.9',
#  'title': '도라지차 10입(피라미드)'}
# 2020-07-08 08:20:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/5663> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/5663>
# {'desc': '제주의 화사하고 향긋한 유채와 달달한 꿀을 블렌딩하여 따스한 블렌디드 티입니다.  제주 차밭의 맛과 향을 가벼운 가격으로 '
#          '즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/ZQ/OJ/20181219114649873QK.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/5663',
#  'price': '8,500',
#  'star': '4.5',
#  'title': '제주유채&꿀티 20입(티백)'}
# 2020-07-08 08:20:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/5661> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16969> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/5661>
# {'desc': '어린 찻잎만을 살짝 찌고 덖어, 부드럽고 깔끔한 맛의 녹차입니다. 제주 차밭의 맛과 향을 가벼운 가격으로 즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/DE/LJ/20160829162706506NY.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/5661',
#  'price': '8,500',
#  'star': '4.7',
#  'title': '제주순수녹차 20입(티백)'}
# 2020-07-08 08:20:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16969>
# {'desc': '달큰한 배향이 달빛처럼 은은하게 감도는 후발효차를 처음 접하시거나 다양한 차를 조금씩 맛보고 싶으시다면, 3입 제품으로 '
#          '합리적인 가격에 체험해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/CH/LY/20191216151744449DV.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16969',
#  'price': '4,500',
#  'star': '4.7',
#  'title': '달빛걷기 3입(피라미드)'}
# 2020-07-08 08:20:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16974> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/6243> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16972> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16974>
# {'desc': '제주 계화향의 우아함과 사과의 풋풋함이 조화를 이룬 블렌디드티',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/FK/MV/20191216155041847ZA.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16974',
#  'price': '12,000',
#  'star': '4.8',
#  'title': '달꽃이 바라보는 바당 10입(피라미드)'}
# 2020-07-08 08:20:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/6243>
# {'desc': '제주 꽃길에서 느꼈던 설렘의 향기와 달콤했던 사랑의 추억을 떠 올려줄제주 꽃을 모티브로 한 티 4종 세트입니다. 간단 '
#          '선물로 추천드립니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/AT/DV/20200604122314580MF.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/6243',
#  'price': '6,000',
#  'star': '4.7',
#  'title': '메모리인제주 4입'}
# 2020-07-08 08:20:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16972>
# {'desc': '제주 귤꽃향의 싱그러움에 감귤의 상큼함을 더한 블렌디드티를 소중한 사람에게 선물해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/TX/PV/20191216154501374VJ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16972',
#  'price': '12,000',
#  'star': '4.8',
#  'title': '귤꽃향을 품은우잣담 10입(피라미드)'}
# 2020-07-08 08:20:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/6044> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/6044>
# {'desc': '제주의 아름다운 숨은 비경을 담은 블렌디드 티 모음 세트 입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/TT/YD/20200624152924492EQ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/6044',
#  'price': '27,000',
#  'star': '4.7',
#  'title': '신오브제주세트(15입)'}
# 2020-07-08 08:20:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16966> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17063> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16966>
# {'desc': '제주 왕벚꽃향의 화사함에 달콤새콤한 과실향이 어우러진 블렌디드티를 소중한 사람에게 선물해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/TY/FT/20191216150008990JZ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16966',
#  'price': '12,000',
#  'star': '4.9',
#  'title': '벚꽃향가득한올레 10입 (피라미드)'}
# 2020-07-08 08:20:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17063>
# {'desc': '제주 왕벚꽃향의 화사함에 달콤새콤한 과실향이 어우러진 블렌디드티\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/CS/TM/20200103140038011DF.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17063',
#  'price': '18,400',
#  'star': '4.8',
#  'title': '벚꽃향가득한올레 20입(피라미드)'}
# 2020-07-08 08:20:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16126> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/5664> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16947> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16126>
# {'desc': '에메랄드빛 제주 바다를 닮은 머스캣향 아이스티입니다. 찬물에도 잘 우러나와 간편하게 즐기실 수 있습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/QM/DY/20190528170613904GT.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16126',
#  'price': '24,000',
#  'star': '4.9',
#  'title': '산호섬 (20입)*2ea'}
# 2020-07-08 08:20:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/5664>
# {'desc': '제주 동백꽃의 달큰한 향미가 아찔하고 짙은 정열적이고 매혹적인 블렌디드 티입니다.  제주 차밭의 맛과 향을 가벼운 가격으로 '
#          '즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/GC/HY/20160829162553549AQ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/5664',
#  'price': '8,500',
#  'star': '4.6',
#  'title': '제주동백꽃티 20입(티백)'}
# 2020-07-08 08:20:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/15585> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16947>
# {'desc': '1년에 단 10일만을 꽃 피우는 제주한란의 청아한 향을 담은 오리엔탈 그린티를 피라미드 티백으로 간편하게, 합리적인 '
#          '가격으로 즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/OH/BQ/20191213162430043PW.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16947',
#  'price': '18,400',
#  'star': '4.9',
#  'title': '제주난꽃향그린티 20입(피라미드)'}
# 2020-07-08 08:20:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16352> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/15585>
# {'desc': '싱그러운 여름 향기와 달큰한 과즙이 가득한 블루베리 블렌디드 티입니다. 달콤상큼한 블루베리를 좋아하시는 분께 추천합니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/EZ/KC/20181203110323350IP.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/15585',
#  'price': '12,000',
#  'star': '4.1',
#  'title': '곱들락한 블루베리 10입(피라미드)'}
# 2020-07-08 08:20:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16346> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16352>
# {'desc': '제주의 따뜻한 햇살로 약발효한 부드러운 향미의 우롱차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/QF/OV/20191104184148887FE.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16352',
#  'price': '15,000',
#  'star': '5.0',
#  'title': '청우롱 10입'}
# 2020-07-08 08:20:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16346>
# {'desc': '상쾌하고 맑은 기운을 전하는 건강차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/FU/NE/20191014204437706IW.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16346',
#  'price': '35,000',
#  'star': '4.8',
#  'title': '도라지차 80g(잎차)'}
# 2020-07-08 08:20:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/17446> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/17446>
# {'desc': '귤꽃과 동백의 향이 가득한 제주 꽃길을 걷는 듯한 블렌디드 티 세트입니다.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/UX/XI/20200311160112456HQ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/17446',
#  'price': '33,000',
#  'star': '4.9',
#  'title': '꽃길만 걸어요(귤꽃, 동백)'}
# 2020-07-08 08:20:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17587> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17587>
# {'desc': '올해의 덖음차 햇차는 모두 판매 완료되었습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/WY/XS/20200424132957799SW.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17587',
#  'price': '15,000',
#  'star': '4.9',
#  'title': '덖음차 50g (햇차, 2020)'}
# 2020-07-08 08:20:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16187> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17588> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16351> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/15143> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16187>
# {'desc': '휴대성이 좋은 달빛걷기 이미지의 오설록 보틀과 함께 에메랄드빛 제주 바다를 닮은 머스캣향 아이스티를 시원하게 '
#          '즐기세요.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/LF/LY/20200227103445494IN.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16187',
#  'price': '16,500',
#  'star': '4.6',
#  'title': '달빛보틀 + 산호섬 20입(아이스티)'}
# 2020-07-08 08:20:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17588>
# {'desc': '올해의 우전 햇차(잎차)는 모두 판매 완료되었습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/KE/FN/20200424133642808TY.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17588',
#  'price': '70,000',
#  'star': '4.5',
#  'title': '우전 60g (햇차, 2020)'}
# 2020-07-08 08:20:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16351>
# {'desc': '제주의 따뜻한 햇살로 약발효한 부드러운 향미의 우롱차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/MK/SY/20190919203416066QE.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16351',
#  'price': '35,000',
#  'star': '4.9',
#  'title': '청우롱 50g(잎차)'}
# 2020-07-08 08:20:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/15143>
# {'desc': '제주만의 특별함을 담아내어 블렌딩한 프리미엄 티백 라인입니다. 제주순수녹차를 포함한 세트로, 당신의 순수한 마음을 '
#          '선물하기에 좋습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/CJ/EF/20180403120431321HP.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/15143',
#  'price': '27,500',
#  'star': '5.0',
#  'title': '순수 박스'}
# 2020-07-08 08:20:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/13943> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16144> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/13943>
# {'desc': '고급감이 느껴지는 우드 케이스로 품격있는 선물로 최적의 가치를 드리는 오설록의 명차세트 입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/FA/MG/20180716152531661KO.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/13943',
#  'price': '120,000',
#  'star': '4.9',
#  'title': '프리미엄 티 기프트 세트'}
# 2020-07-08 08:20:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16144>
# {'desc': '찬물에 잘 우러나는 녹차입니다. 언제어디서나 쉽고 간편하게 우려먹는 스틱형 찬물녹차로 간편한 티라이프를 즐기세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/RD/TN/20200706095544295GI.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16144',
#  'price': '20,400',
#  'star': '4.9',
#  'title': '찬물녹차(스틱) 20ea * 3개'}
# 2020-07-08 08:20:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16044> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16044>
# {'desc': '해당 제품은 단종되었습니다. 더 좋은 제품으로 찾아뵙겠습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/LA/VF/20190416162326756NH.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16044',
#  'price': '25,000',
#  'star': '4.4',
#  'title': '제주숲 동화 3종 미니 세트'}
# 2020-07-08 08:20:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16123> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16354> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16349> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17783> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16358> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/15584> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16123>
# {'desc': '제주 여름밤의 시원함을 담은 배향 아이스티입니다. 찬물에도 잘 우러나와 간편하게 즐기실 수 있습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/YL/AZ/20190528165157929RE.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16123',
#  'price': '24,000',
#  'star': '4.8',
#  'title': '달빛섬 (20입)*2ea'}
# 2020-07-08 08:20:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/15144> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16354>
# {'desc': '한라산의 화산암석층이 키워낸 구수한 풍미의 반발효차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/GR/GH/20190919203651744II.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16354',
#  'price': '12,000',
#  'star': '4.4',
#  'title': '제주화산암차 10입(피라미드)'}
# 2020-07-08 08:20:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16349>
# {'desc': '기분좋은 상쾌함을 선사하는 허브차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/XM/BL/20191014204308564QF.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16349',
#  'price': '20,000',
#  'star': '4.6',
#  'title': '모로칸민트티 16g(잎차)'}
# 2020-07-08 08:20:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17783>
# {'desc': '구강에서의 항균 작용에 도움을 줄 수 있는 프로폴리스 추출물 건강기능식품',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/HA/AS/20200630235430591PQ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17783',
#  'price': '12,000',
#  'star': '4.7',
#  'title': '오설록 프로폴리스 스프레이 25ml'}
# 2020-07-08 08:20:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16358>
# {'desc': '제주 숲 차밭의 어린 찻잎으로 만든 산뜻한 향미의 홍차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/KS/OS/20190919204513185CW.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16358',
#  'price': '15,000',
#  'star': '4.8',
#  'title': '제주숲홍차 10입(피라미드)'}
# 2020-07-08 08:20:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/15584>
# {'desc': '트로피컬 풍미와 달콤한 과즙이 가득한 망고 블렌디드 티입니다. 달콤한 향의 망고를 좋아하시는 분께 추천합니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/OC/IT/20181203110401801ED.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/15584',
#  'price': '12,000',
#  'star': '4.5',
#  'title': '돌코롬 망고 10입(피라미드)'}
# 2020-07-08 08:20:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/15144>
# {'desc': '제주만의 특별함을 담아내어 블렌딩한 프리미엄 티백 라인입니다. 그 중에서도 달달한 맛과 향을 가진 제품을 3가지 모은 '
#          '세트입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/RH/LB/20180403121530820RY.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/15144',
#  'price': '27,500',
#  'star': '4.7',
#  'title': '달달 박스'}
# 2020-07-08 08:20:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17068> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17068>
# {'desc': '정통 발효차인 제주 흑차를 갈아 담아 구수하고 중후한 풍미의 가루차',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/TH/UR/20200103142150590NT.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17068',
#  'price': '13,000',
#  'star': '4.3',
#  'title': '가루발효차 40 g(분말)'}
# 2020-07-08 08:20:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16356> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16362> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16712> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1)
# 2020-07-08 08:20:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17828> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-07-08 08:20:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/15103> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16353> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-07-08 08:20:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17827> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-07-08 08:20:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16356>
# {'desc': '제주 삼나무로 오랜 시간 숙성시킨 깊고 부드러운 후발효차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/GV/HN/20190919204230223ZD.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16356',
#  'price': '15,000',
#  'star': '4.6',
#  'title': '삼다연 10입(피라미드)'}
# 2020-07-08 08:20:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16362>
# {'desc': '조화로운 풍미와 오설록 역사를 간직한 녹차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/EP/SJ/20190919204835704PK.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16362',
#  'price': '12,000',
#  'star': '4.8',
#  'title': '억수진 10입(피라미드)'}
# 2020-07-08 08:20:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16712>
# {'desc': '1년에 단 10일만을 꽃 피우는 제주한란의 청아한 향을 담은 오리엔탈 그린티입니다. 소중한 사람에게 선물해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/PU/NA/20191017180949089IL.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16712',
#  'price': '12,000',
#  'star': '4.8',
#  'title': '제주난꽃향그린티 10입(피라미드)'}
# 2020-07-08 08:20:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17828>
# {'desc': '#Good Hydration 몸 속 수분 밸런스를 위한 습관 형성에 도움을 주는 워터플러스 체리플럼과 제주 동백꽃 아스 '
#          '텀블러 구성 세트',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/TC/NS/20200622160614316IH.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17828',
#  'price': '15,750',
#  'star': '0.0',
#  'title': '내일 더 촉촉해지는 습관 세트'}
# 2020-07-08 08:20:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17584> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-07-08 08:20:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/15103>
# {'desc': '녹차스프레드와 별도 포장이 필요 없는 고급 패키지로 구성된 쨈 2종 세트입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/WY/UK/20180319145258513JZ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/15103',
#  'price': '19,000',
#  'star': '4.6',
#  'title': '녹차밀크스프레드 2입 지함 세트'}
# 2020-07-08 08:20:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16353>
# {'desc': '한라산의 화산암석층이 키워낸 구수한 풍미의 반발효차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/GG/VX/20190919203609252BV.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16353',
#  'price': '35,000',
#  'star': '4.8',
#  'title': '제주화산암차 50g(잎차)'}
# 2020-07-08 08:20:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17827>
# {'desc': '#SKINNY LIFE 어제보다 가벼운 오늘을 위한 습관 형성에 도움을 주는 워터플러스 깔라망고와 제주 계화꽃 아이스 '
#          '텀블러 구성 세트',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/JU/XQ/20200622160505074EW.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17827',
#  'price': '15,750',
#  'star': '0.0',
#  'title': '내일 더 가벼워지는 습관 세트'}
# 2020-07-08 08:20:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17584>
# {'desc': '제주 차밭의 어린 찻잎으로 만든 작설차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/ZQ/TI/20200424132204869ZU.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17584',
#  'price': '20,000',
#  'star': '5.0',
#  'title': '세작 10입 (햇차, 2020)'}
# 2020-07-08 08:20:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17589> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-07-08 08:20:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17144> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-07-08 08:20:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17589>
# {'desc': '가장 먼저 딴 여린 차순을 정성스레 덖어낸 오설록 고급 우전차입니다. 피라미드 티백으로 간편하게 고급스러운 티타임을 '
#          '즐기세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/LO/TY/20200424133913373EO.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17589',
#  'price': '25,000',
#  'star': '5.0',
#  'title': '우전 10입 (햇차, 2020)'}
# 2020-07-08 08:20:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17563> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-07-08 08:20:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17144>
# {'desc': '달콤하게 즐기는 블렌디드 루이보스차',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/GI/MA/20200131110741168FM.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17144',
#  'price': '15,000',
#  'star': '5.0',
#  'title': '루이보스 카라멜베리 10입(피라미드)'}
# 2020-07-08 08:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17563>
# {'desc': '카페인이 없는 티 세트로 사랑하는 마음을 전해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/FJ/YZ/20200423115725302JB.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17563',
#  'price': '33,000',
#  'star': '5.0',
#  'title': '엄마아빠사랑해요(도라지, 루이보스)'}
# 2020-07-08 08:20:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17143> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-07-08 08:20:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17143>
# {'desc': '붉은 태양을 닮은 깊은 풍미의순수 루이보스차\r\n',
# ...
#  'price': '15,000',
#  'star': '4.4',
#  'title': '달빛걷기 35 g(잎차)'}
# 2020-07-08 08:21:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/2684>
# {'desc': '향긋한 차의 세계를 경험할 수 있는 오설록의 블렌디드 티 베스트 3종을 모아 둔 티 컬렉션입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/BP/LG/20171110104835223PV.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/2684',
#  'price': '47,000',
#  'star': '4.9',
#  'title': '베스트티컬렉션 3종'}
# 2020-07-08 08:21:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16979> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-07-08 08:21:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17686> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-07-08 08:21:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16765> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-07-08 08:21:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/15524> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-07-08 08:21:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16973> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-07-08 08:21:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16979>
# {'desc': '발효차 삼다연 베이스에 제주영귤을 블렌딩한 밀크티입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/IQ/CA/20191216160509965SK.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16979',
#  'price': '12,000',
#  'star': '4.6',
#  'title': '삼다연제주영귤밀크티 10입'}
# 2020-07-08 08:21:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17686>
# {'desc': '3가지 맛 워터플러스를 모두 맛볼 수 있는 온라인 전용 상품',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/GU/DD/20200707155703680MM.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17686',
#  'price': '17,000',
#  'star': '4.9',
#  'title': '워터플러스 버라이어티팩 30입'}
# 2020-07-08 08:21:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16765>
# {'desc': '신부의 부케가 꽃향이 만발하는 한잔의 차가 되었습니다. 다양한 차를 조금씩 맛보고 싶으시다면, 3입 제품으로 합리적인 '
#          '가격에 체험해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/RY/TV/20191101134258858GR.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16765',
#  'price': '3,600',
#  'star': '4.3',
#  'title': '웨딩그린티 3입(피라미드)'}
# 2020-07-08 08:21:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/15524>
# {'desc': '제주 숲 동화 4종으로 구성된 기프트 세트',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/SM/OU/20180904173031662SD.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/15524',
#  'price': '35,000',
#  'star': '4.6',
#  'title': '제주숲 동화 4종 세트'}
# 2020-07-08 08:21:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16973>
# {'desc': '제주 귤꽃향의 싱그러움에 감귤의 상큼함을 더한 블렌디드티를 처음 접하시거나 다양한 차를 조금씩 맛보고 싶으시다면, 3입 '
#          '제품으로 합리적인 가격에 체험해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/WG/FX/20191216154725956FZ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16973',
#  'price': '4,500',
#  'star': '4.5',
#  'title': '귤꽃향을 품은우잣담 3입(피라미드)'}
# 2020-07-08 08:21:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17685> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-07-08 08:21:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17685>
# {'desc': '#Good Hydration 몸 속 수분  밸런스를 위한  습관  차',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/PX/OD/20200528111714126HS.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17685',
#  'price': '9,000',
#  'star': '4.7',
#  'title': '워터플러스 체리플럼 15입'}
# 2020-07-08 08:21:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16764> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-07-08 08:21:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16764>
# {'desc': '붉은 장미와 달콤한 파파야가 곁들여진 화려한 풍미의 홍차를 처음 접하시거나 다양한 차를 조금씩 맛보고 싶으시다면, 3입 '
#          '제품으로 합리적인 가격에 체험해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/WR/GA/20191101134248544TF.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16764',
#  'price': '4,500',
#  'star': '4.8',
#  'title': '레드파파야블랙티 3입(피라미드)'}
# 2020-07-08 08:21:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16713> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-07-08 08:21:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16713>
# {'desc': '달콤 쌉싸름한 아포가토향이 은은하게 퍼지는 블렌디드티를 고급스러운 지함에 담았습니다. 소중한 사람에게 선물해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/RE/IZ/20191017181033328JU.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16713',
#  'price': '12,000',
#  'star': '4.6',
#  'title': '바닐라에스프레소 10입(피라미드)'}
# 2020-07-08 08:21:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16983> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:21:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16359> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:21:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/6187> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:21:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17066> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:21:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16983>
# {'desc': '제주 오설록 직영 차밭에서 100% 유기농으로 재배한 프리미엄 가루 녹차입니다. 어디에나 간편하게 톡톡 뿌려 즐기실 수 '
#          '있습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/HJ/HP/20191217102813480PT.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16983',
#  'price': '10,000',
#  'star': '4.5',
#  'title': '가루녹차 40g'}
# 2020-07-08 08:21:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16359>
# {'desc': '제주 차밭의 어린 찻잎으로 만든 작설차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/DA/ZO/20190919204622803GY.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16359',
#  'price': '40,000',
#  'star': '4.8',
#  'title': '세작 80g(잎차)'}
# 2020-07-08 08:21:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/6187>
# {'desc': '에메랄드빛 제주 바다를 닮은 머스캣향 아이스티입니다. 찬물에도 잘 우러나와 간편하게 즐기실 수 있습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/IN/XS/20180716000103719MT.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/6187',
#  'price': '8,400',
#  'star': '4.6',
#  'title': '산호섬 20입(아이스티)'}
# 2020-07-08 08:21:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17066>
# {'desc': ' 제주 동백꽃향과 열대과일의 달콤한 풍미가 매력적인 블렌디드티   \r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/SW/RN/20200103141443564RH.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17066',
#  'price': '18,400',
#  'star': '4.9',
#  'title': '동백이피는곶자왈 20입(피라미드)'}
# 2020-07-08 08:21:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/4526> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:21:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16643> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:21:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17083> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:21:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/4526>
# {'desc': '제주 꽃길에서 느꼈던 설렘의 향기와 달콤했던 사랑의 추억을 떠 올려줄 제주 꽃을 모티브로 한 BEST TEA SET '
#          '입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/NP/YV/20200513135231693GB.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/4526',
#  'price': '38,000',
#  'star': '4.8',
#  'title': '메모리인제주세트 20입'}
# 2020-07-08 08:21:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16643>
# {'desc': '제주 차밭의 어린 찻잎으로 만든 작설차를 원하는 용량만큼 우려드실 수 있는 잎차입니다. 합리적인 가격에 즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/VV/RX/20191007135642767XI.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16643',
#  'price': '17,000',
#  'star': '4.7',
#  'title': '세작 40 g(잎차)'}
# 2020-07-08 08:21:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17083>
# {'desc': '달큰한 배향이 달빛처럼 은은하게 감도는 후발효차',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/DF/DY/20200110161302294EE.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17083',
#  'price': '23,000',
#  'star': '4.7',
#  'title': '달빛걷기 20입(피라미드)'}
# 2020-07-08 08:21:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/15263> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:21:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16946> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:21:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16711> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:21:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/6362> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:21:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16623> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:21:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/15263>
# {'desc': '즐거운 티타임을 위해 다양한 맛과 향을 담은 프리미엄 티백 세트',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/BK/ZR/20180904143404408UV.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/15263',
#  'price': '25,000',
#  'star': '4.7',
#  'title': '프리미엄 티 컬렉션'}
# 2020-07-08 08:21:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16946>
# {'desc': '신부의 부케가 꽃향이 만발하는 한잔의 차가 되었습니다.  피라미드 티백으로 간편하게, 합리적인 가격으로 즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/KR/TP/20191213162107079MN.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16946',
#  'price': '23,000',
#  'star': '4.8',
#  'title': '웨딩그린티 20입(피라미드)'}
# 2020-07-08 08:21:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16711>
# {'desc': '신부의 부케가 꽃향이 만발하는 한잔의 차가 되었습니다. 소중한 사람에게 고급스러운 지함에 담긴 차를 선물해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/ZM/MG/20191017180911427IU.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16711',
#  'price': '15,000',
#  'star': '4.9',
#  'title': '웨딩그린티 10입(피라미드)'}
# 2020-07-08 08:21:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/6362>
# {'desc': '찬물에 잘 우러나는 녹차입니다. 언제어디서나 쉽고 간편하게 우려먹는 스틱형 찬물녹차로 간편한 티라이프를 즐기세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/II/US/20200707155618911DS.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/6362',
#  'price': '6,800',
#  'star': '4.8',
#  'title': '찬물녹차 20입(아이스티)'}
# 2020-07-08 08:21:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16623>
# {'desc': '제주 차밭의 어린 찻잎으로 만든 작설차를 피라미드 티백으로 간편하게, 합리적인 가격으로 즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/OA/EO/20200707155646390AC.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16623',
#  'price': '17,500',
#  'star': '4.9',
#  'title': '세작 20입(피라미드)'}
# 2020-07-08 08:21:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16945> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:21:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16710> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:21:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16943> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-07-08 08:21:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16945>
# {'desc': '붉은 장미와 달콤한 파파야가 곁들여진 화려한 풍미의 홍차를 피라미드 티백으로 간편하게, 합리적인 가격으로 즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/CV/PI/20191213161646687QE.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16945',
#  'price': '23,000',
#  'star': '4.8',
#  'title': '레드파파야블랙티 20입(피라미드)'}
# 2020-07-08 08:21:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16710>
# {'desc': '붉은 장미와 달콤한 파파야가 곁들여진 화려한 풍미의 홍차를 고급스러운 지함에 담았습니다. 소중한 사람에게 선물해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/CL/OM/20191017180835875SU.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16710',
#  'price': '15,000',
#  'star': '4.9',
#  'title': '레드파파야블랙티 10입(피라미드)'}
# 2020-07-08 08:21:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16943>
# {'desc': '제주 삼나무의 그윽한 풍미에 제주영귤의 싱그러움을 더한 후발효차를 피라미드 티백으로 간편하게, 합리적인 가격으로 '
#          '즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/ZM/SS/20191213160304931SR.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16943',
#  'price': '18,400',
#  'star': '4.9',
#  'title': '삼다연제주영귤 20입(피라미드)'}
# 2020-07-08 08:21:07 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-07-08 08:21:07 [scrapy.extensions.feedexport] INFO: Stored csv feed (151 items) in: osulloc_teashop.csv
# 2020-07-08 08:21:07 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 63429,
#  'downloader/request_count': 160,
#  'downloader/request_method_count/GET': 160,
#  'downloader/response_bytes': 8891006,
#  'downloader/response_count': 160,
#  'downloader/response_status_count/200': 160,
#  'elapsed_time_seconds': 37.5774,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 7, 7, 23, 21, 7, 475166),
#  'item_scraped_count': 151,
#  'log_count/DEBUG': 311,
#  'log_count/INFO': 11,
#  'memusage/max': 58454016,
#  'memusage/startup': 58454016,
#  'request_depth_max': 2,
#  'response_received_count': 160,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 159,
#  'scheduler/dequeued/memory': 159,
#  'scheduler/enqueued': 159,
#  'scheduler/enqueued/memory': 159,
#  'start_time': datetime.datetime(2020, 7, 7, 23, 20, 29, 897766)}
# 2020-07-08 08:21:07 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# 크롤링 결과 확인

# %%
df = pd.read_csv("osulloc/osulloc_teashop.csv")

# %%
df.tail(2)
# Out:
#                                                   desc  \
# 149  붉은 장미와 달콤한 파파야가 곁들여진 화려한 풍미의 홍차를 고급스러운 지함에 담았습...
# 150  제주 삼나무의 그윽한 풍미에 제주영귤의 싱그러움을 더한 후발효차를 피라미드 티백으로...
#
#                                                    img  \
# 149  https://www.osulloc.com/upload/kr/ko/adminImag...
# 150  https://www.osulloc.com/upload/kr/ko/adminImag...
#
#                                                   link   price  star  \
# 149  https://www.osulloc.com/kr/ko/shop/item/teasho...  15,000   4.9
# 150  https://www.osulloc.com/kr/ko/shop/item/teasho...  18,400   4.9
#
#                   title
# 149  레드파파야블랙티 10입(피라미드)
# 150   삼다연제주영귤 20입(피라미드)

# %%
# 데이터 베이스 저장 확인

# %%
import pymongo

client = pymongo.MongoClient('mongodb://rada:radapw@15.164.104.167:27017')
db = client.osulloc
collection = db.items

# %%
datas = collection.find({}, {"_id": False})

# %%
pd.DataFrame(datas).tail(2)
# Out:
#                   title                                               desc  \
# 149  레드파파야블랙티 10입(피라미드)  붉은 장미와 달콤한 파파야가 곁들여진 화려한 풍미의 홍차를 고급스러운 지함에 담았습...
# 150   삼다연제주영귤 20입(피라미드)  제주 삼나무의 그윽한 풍미에 제주영귤의 싱그러움을 더한 후발효차를 피라미드 티백으로...
#
#       price star                                                img  \
# 149  15,000  4.9  https://www.osulloc.com/upload/kr/ko/adminImag...
# 150  18,400  4.9  https://www.osulloc.com/upload/kr/ko/adminImag...
#
#                                                   link
# 149  https://www.osulloc.com/kr/ko/shop/item/teasho...
# 150  https://www.osulloc.com/kr/ko/shop/item/teasho...
